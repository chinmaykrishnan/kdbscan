# %% [markdown]
# ## Abalone Data Clustering

# %% [markdown]
# Steps:
# 1. Load the abalone dataset from the uciml repo python library
# 2. Extract the features
# 3. Perform KMeans clustering using KMeans++ for the initialised centroids
# 4. Merge clusters based on a defined distance formula and *ε* such that two clusters are merged if the distance between them, *d* < *ε*
# 5. On each of the clusters obtained in step 4, perform DBSCAN

# %% [markdown]
# References:
# 1. https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html#sklearn.cluster.KMeans
# 2. https://scikit-learn.org/stable/modules/generated/sklearn.cluster.DBSCAN.html
# 3. http://archive.ics.uci.edu/dataset/1/abalone

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from ucimlrepo import fetch_ucirepo
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans, DBSCAN 
from scipy.spatial.distance import cdist

# %%
# fetch abalone dataset 
abalone = fetch_ucirepo(id=1) 
  
# data is stored as pandas dataframes
X = abalone.data.features 
y = abalone.data.targets
# Out:
#   Cell In[3], line 4
#     data (as pandas dataframes)
#           ^
# SyntaxError: invalid syntax

# %%
# Features
X.head(10)
# Out:
#     fLength    fWidth   fSize   fConc  fConc1     fAsym  fM3Long  fM3Trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
# 5   51.6240   21.1502  2.9085  0.2420  0.1340   50.8761  43.1887    9.8145
# 6   48.2468   17.3565  3.0332  0.2529  0.1515    8.5730  38.0957   10.5868
# 7   26.7897   13.7595  2.5521  0.4236  0.2174   29.6339  20.4560   -2.9292
# 8   96.2327   46.5165  4.1540  0.0779  0.0390  110.3550  85.0486   43.1844
# 9   46.7619   15.1993  2.5786  0.3377  0.1913   24.7548  43.8771   -6.6812
#
#     fAlpha     fDist
# 0  40.0920   81.8828
# 1   6.3609  205.2610
# 2  76.9600  256.7880
# 3  10.4490  116.7370
# 4   4.6480  356.4620
# 5   3.6130  238.0980
# 6   4.7920  219.0870
# 7   0.8120  237.1340
# 8   4.8540  248.2260
# 9   7.8750  102.2510

# %%
# Checking the stats of the features

X.info()
X.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19020 entries, 0 to 19019
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   fLength   19020 non-null  float64
#  1   fWidth    19020 non-null  float64
#  2   fSize     19020 non-null  float64
#  3   fConc     19020 non-null  float64
#  4   fConc1    19020 non-null  float64
#  5   fAsym     19020 non-null  float64
#  6   fM3Long   19020 non-null  float64
#  7   fM3Trans  19020 non-null  float64
#  8   fAlpha    19020 non-null  float64
#  9   fDist     19020 non-null  float64
# dtypes: float64(10)
# memory usage: 1.5 MB
#             fLength        fWidth         fSize         fConc        fConc1  \
# count  19020.000000  19020.000000  19020.000000  19020.000000  19020.000000
# mean      53.250154     22.180966      2.825017      0.380327      0.214657
# std       42.364855     18.346056      0.472599      0.182813      0.110511
# min        4.283500      0.000000      1.941300      0.013100      0.000300
# 25%       24.336000     11.863800      2.477100      0.235800      0.128475
# 50%       37.147700     17.139900      2.739600      0.354150      0.196500
# 75%       70.122175     24.739475      3.101600      0.503700      0.285225
# max      334.177000    256.382000      5.323300      0.893000      0.675200
#
#               fAsym       fM3Long      fM3Trans        fAlpha         fDist
# count  19020.000000  19020.000000  19020.000000  19020.000000  19020.000000
# mean      -4.331745     10.545545      0.249726     27.645707    193.818026
# std       59.206062     51.000118     20.827439     26.103621     74.731787
# min     -457.916100   -331.780000   -205.894700      0.000000      1.282600
# 25%      -20.586550    -12.842775    -10.849375      5.547925    142.492250
# 50%        4.013050     15.314100      0.666200     17.679500    191.851450
# 75%       24.063700     35.837800     10.946425     45.883550    240.563825
# max      575.240700    238.321000    179.851000     90.000000    495.561000

# %%
# Target column to be discarded
# y.head()

# %%
# Standardising

scaler  = StandardScaler()
scaled_X = pd.DataFrame(scaler.fit_transform(X[X.columns]), columns = X.columns)

# %%
# Scaling/standardizing the features

# scaled_X = X
# scaler = StandardScaler()
# scaled_X[
#     ['Length', 'Diameter', 'Height',
#      'Whole_weight', 'Shucked_weight',
#      'Viscera_weight', 'Shell_weight']] = scaler.fit_transform(scaled_X[
#     ['Length', 'Diameter', 'Height',
#      'Whole_weight', 'Shucked_weight',
#      'Viscera_weight', 'Shell_weight']])

# scaled_X

# %%
# creating a dataframe to store scaled features

abalone = scaled_X
abalone.head()
# Out:
#     fLength    fWidth     fSize     fConc    fConc1     fAsym   fM3Long  \
# 0 -0.577226 -0.336804 -0.381130  0.062759 -0.148923  0.541042  0.224818
# 1 -0.510969 -0.570027 -0.648595  0.820383  1.471776  0.516919  0.260364
# 2  2.568278  6.205858  2.615783 -1.875883 -1.773241  2.044992 -1.478536
# 3 -0.694768 -0.687259 -1.029478  1.282069  1.606608  0.532771 -0.333515
# 4  0.516622  0.476384  0.711157 -0.347506 -0.284660 -0.020200  0.353086
#
#    fM3Trans    fAlpha     fDist
# 0 -0.405842  0.476816 -1.497866
# 1 -0.490094 -0.815418  0.153125
# 2 -2.183030  1.889224  0.842635
# 3 -0.355359 -0.658804 -1.031463
# 4  1.036620 -0.881039  2.176427

# %%
# Label encoding the Sex column

# abalone['Sex'] = LabelEncoder().fit_transform(abalone['Sex'])
# abalone.head()

# %%
# # Alternative - dropping the Sex column
# abalone = abalone.drop(['Sex'], axis=1)
# abalone

# %% [markdown]
# #### KMeans++ clustering on abalone/MAGIC dataset

# %%
# Running KMeans++ on abalone data n_clust=3

# km_abalone = KMeans(init='k-means++', n_clusters=3, random_state=69, n_init="auto").fit(abalone)
# km_abalone.labels_

# %%
# number of clusters as proposed in the paper = sqrt(n_samples)
import math
num_clusters = math.floor(np.sqrt([len(abalone)])[0])
num_clusters
# Out:
# 137

# %%
abalone
# Out:
#         fLength    fWidth     fSize     fConc    fConc1     fAsym   fM3Long  \
# 0     -0.577226 -0.336804 -0.381130  0.062759 -0.148923  0.541042  0.224818
# 1     -0.510969 -0.570027 -0.648595  0.820383  1.471776  0.516919  0.260364
# 2      2.568278  6.205858  2.615783 -1.875883 -1.773241  2.044992 -1.478536
# 3     -0.694768 -0.687259 -1.029478  1.282069  1.606608  0.532771 -0.333515
# 4      0.516622  0.476384  0.711157 -0.347506 -0.284660 -0.020200  0.353086
# ...         ...       ...       ...       ...       ...       ...       ...
# 19015 -0.752189 -0.613988 -0.442072  1.123433  1.617467  0.330947  0.019196
# 19016 -0.573721 -0.843744 -1.180350  0.846640  0.576817  0.699497  0.051761
# 19017  0.523923  1.381779  1.318877 -1.305340 -1.445663 -0.084864  0.598262
# 19018  1.587757  2.982781  2.473375 -1.564081 -1.324404  0.171204 -2.040597
# 19019  3.161459  1.679993  0.813149 -0.507237 -0.549799 -2.752844 -3.509914
#
#        fM3Trans    fAlpha     fDist
# 0     -0.405842  0.476816 -1.497866
# 1     -0.490094 -0.815418  0.153125
# 2     -2.183030  1.889224  0.842635
# 3     -0.355359 -0.658804 -1.031463
# 4      1.036620 -0.881039  2.176427
# ...         ...       ...       ...
# 19015  0.126129 -0.966282 -1.164090
# 19016 -0.154268  2.266097  0.717759
# 19017 -0.466509  0.101636  0.839003
# 19018 -3.077206  2.185260  2.870321
# 19019  1.499301  0.961014  1.050442
#
# [19020 rows x 10 columns]

# %%
# Running KMeans++ with num_clusters
km_abalone = KMeans(init='k-means++', n_clusters=num_clusters, random_state=69, n_init='auto', max_iter=4).fit(abalone)
km_abalone.labels_
# Out:
# array([  5,  69,  85, ..., 112,  35,  96])

# %%
# Retrieving KMeans cluster centroids
km_abalone.cluster_centers_
# Out:
# array([[-2.52926029e-01, -3.45254084e-01, -2.23634872e-01, ...,
#         -1.23526336e-01, -6.77090299e-01, -1.63911395e-01],
#        [-6.65849011e-01, -5.82437741e-01, -8.17758055e-01, ...,
#         -2.05475474e-01, -3.57687951e-01, -4.46933260e-01],
#        [ 7.30076184e-01,  4.58249352e-01,  1.25595462e+00, ...,
#          9.20515257e-01, -8.39472615e-01,  1.74270122e+00],
#        ...,
#        [-6.92875731e-01, -6.05535389e-01, -1.02288546e+00, ...,
#         -2.59791067e-02, -6.38175886e-01, -6.82779535e-01],
#        [-8.67755255e-01, -7.74348098e-01, -1.09015442e+00, ...,
#         -1.37556539e-03,  3.26285943e-01, -2.42580797e-01],
#        [ 2.67201785e+00,  1.08284467e+00,  9.68665900e-01, ...,
#         -1.38610626e+00,  7.12265897e-01,  6.14726770e-01]])

# %%
# Creating a column to store predicted clusters

cluster = []
for val in km_abalone.labels_:
    cluster_label = "KC"+str(val)
    cluster.append(cluster_label)
# cluster

# %%
# Appending the predicted clusters to our dataset
clustered_abalone = abalone
clustered_abalone['cluster'] = cluster
clustered_abalone.head(10)
# Out:
#     fLength    fWidth     fSize     fConc    fConc1     fAsym   fM3Long  \
# 0 -0.577226 -0.336804 -0.381130  0.062759 -0.148923  0.541042  0.224818
# 1 -0.510969 -0.570027 -0.648595  0.820383  1.471776  0.516919  0.260364
# 2  2.568278  6.205858  2.615783 -1.875883 -1.773241  2.044992 -1.478536
# 3 -0.694768 -0.687259 -1.029478  1.282069  1.606608  0.532771 -0.333515
# 4  0.516622  0.476384  0.711157 -0.347506 -0.284660 -0.020200  0.353086
# 5 -0.038386 -0.056186  0.176651 -0.756678 -0.729877  0.932494  0.640077
# 6 -0.118105 -0.262977  0.440519 -0.697053 -0.571517  0.217969  0.540212
# 7 -0.624601 -0.459046 -0.577497  0.236712  0.024821  0.573700  0.194327
# 8  1.014607  1.326507  2.812149 -1.654340 -1.589544  1.937129  1.460879
# 9 -0.153156 -0.380564 -0.521422 -0.233179 -0.211362  0.491289  0.653576
#
#    fM3Trans    fAlpha     fDist cluster
# 0 -0.405842  0.476816 -1.497866     KC5
# 1 -0.490094 -0.815418  0.153125    KC69
# 2 -2.183030  1.889224  0.842635    KC85
# 3 -0.355359 -0.658804 -1.031463    KC21
# 4  1.036620 -0.881039  2.176427     KC2
# 5  0.459251 -0.920690  0.592534   KC110
# 6  0.496333 -0.875523  0.338138   KC127
# 7 -0.152636 -1.027996  0.579634    KC57
# 8  2.061502 -0.873147  0.728062    KC42
# 9 -0.332787 -0.757413 -1.225308     KC5

# %%
# Storing the samples in each cluster in a dictionary with the cluster name as key and a dataframe with samples belonging
# to those clusters as the value

cluster_samples = {}
labels = set(cluster)
for label in labels:
    cluster_samples[label] = clustered_abalone.loc[clustered_abalone['cluster'] == label]

# %%
# retrieving samples in each cluster

# KC1 = clustered_abalone.loc[clustered_abalone['cluster'] == "KC1"]
# KC2 = clustered_abalone.loc[clustered_abalone['cluster'] == "KC2"]
# KC3 = clustered_abalone.loc[clustered_abalone['cluster'] == "KC3"]

# KC1.head()
# KC2.head()
# KC3.head()

# KC1 - 2163 samples
# KC2 - 1524 samples
# KC3 - 490 samples

# %%
# Defining a function to calculate distance between two groups/clusters
def minC_distance(a, b):
    return np.min(cdist(a, b))

# %%
# We create a similar dictionary to store features of each sample in each cluster

cluster_features = {}
for label in labels:
    cluster_features[label] = cluster_samples[label].drop(['cluster'], axis=1)
cluster_features["KC63"]
# Out:
#         fLength    fWidth     fSize     fConc    fConc1     fAsym   fM3Long  \
# 51    -0.216354  0.045424  0.153164 -1.006667 -1.042976  0.511519 -0.895638
# 215   -0.385907  0.149487  0.555630 -1.065745 -1.058360  0.031389 -0.467240
# 275   -0.295091  0.216305  0.819285 -1.023077 -1.029403  0.579487 -0.689119
# 302   -0.219260 -0.105599  0.648100 -0.936101 -0.956105 -0.386703 -0.610792
# 403    0.061214 -0.039594  0.794951 -0.919143 -0.884617 -0.386681 -0.747717
# ...         ...       ...       ...       ...       ...       ...       ...
# 17605 -0.121426  1.149996  1.347866 -1.588150 -1.296352  0.133806 -0.881344
# 18494 -0.128458  0.971920  0.681744 -1.265955 -1.242962 -0.639422 -0.860276
# 18524  0.394801  0.592853  0.599643 -0.793329 -0.845706 -0.003501 -1.519035
# 18780 -0.407118  0.076020  0.677089 -0.976034 -1.012209 -0.245540 -0.389089
# 18830 -0.148923  1.204587  0.971850 -1.352384 -1.444758 -0.833848 -0.637389
#
#        fM3Trans    fAlpha     fDist
# 51     0.914749 -0.441587  0.224515
# 215    0.377304 -0.983530 -0.786581
# 275    0.416191 -0.738680 -0.330457
# 302    0.675668 -0.796834 -0.056230
# 403    0.468004 -0.851058  0.532183
# ...         ...       ...       ...
# 17605  1.482025 -0.261772 -0.772674
# 18494  1.098550 -0.063123 -1.059992
# 18524  0.925355 -0.104621 -0.194367
# 18780  0.529862  0.271567  0.037896
# 18830  1.608880 -0.460539 -0.538372
#
# [129 rows x 10 columns]

# %%
# Running DBSCAN on each cluster and storing the results
dbscan_clusters = {}

# Running DBSCAN on each cluster:
selected_df = None
for i in range(0, num_clusters):
    label = "KC" + str(i)
    
    current = cluster_features[label] # current dataframe    
    n = len(cluster_features[label]) # total number of samples in the current kmeans cluster
    
    dbscan = DBSCAN(eps=0.6, min_samples=4).fit(cluster_features[label])
    valid_clus = set(dbscan.labels_).difference([-1]) # removing noise points
#     print("Group ", label, " clusters-> ", valid_clus)
    numclu = len(set(valid_clus)) # total number of non-noise DBSCAN clusters identified in the current KMeans cluster
    
    current['db_clus'] = dbscan.labels_ # marking each sample with it's dbscan cluster number
    
    db_samples = {}
    if numclu > 0:
        for p in range(numclu):
            db_samples[str(p)] = current.loc[current['db_clus'] == p].drop(['db_clus'], axis=1)

    dbscan_clusters[label] = db_samples

# %%
dbscan_clusters["KC0"]["2"]
# Out:
#         fLength    fWidth     fSize     fConc    fConc1     fAsym   fM3Long  \
# 1069  -0.001311 -0.407404  0.136659 -0.754490 -0.746165 -0.283153  0.269370
# 2988  -0.227658  0.101323  0.234419 -0.805910 -0.751595 -0.609525  0.250719
# 4749  -0.180649 -0.176738  0.096031 -0.628128 -0.692775 -0.667209  0.539683
# 6915  -0.027678 -0.229067 -0.252053 -0.616094 -0.669248 -0.853044 -0.065199
# 9745  -0.106304 -0.176973  0.087356 -0.666420 -0.705444 -0.663739  0.212136
# 9801  -0.474516 -0.248919 -0.308974 -0.557015 -0.606809 -0.902724  0.225469
# 9816  -0.250305 -0.350977 -0.135038 -0.686659 -0.774217 -0.744823  0.244032
# 10107 -0.016520 -0.257243 -0.360393 -0.687206 -0.749785 -0.700301  0.255937
# 11085 -0.394209 -0.196907 -0.085523 -0.589290 -0.597759 -0.235103  0.061365
# 11883 -0.415732 -0.249742 -0.055687 -0.636881 -0.683726 -0.379219  0.220000
# 11902 -0.479990 -0.168257 -0.240415 -0.804816 -0.878282 -0.173006  0.104715
# 15736 -0.656360 -0.154515 -0.191535 -0.697053 -0.829417 -0.216378  0.184396
# 18812 -0.364908 -0.421108 -0.206347 -0.441594 -0.561563 -0.543482 -0.152038
#
#        fM3Trans    fAlpha     fDist
# 1069   0.366707 -0.955628  0.338874
# 2988   0.494811 -0.795302 -0.339450
# 4749   0.805798 -0.582567 -0.345766
# 6915   0.361282 -0.901612  0.248013
# 9745   0.552045 -0.877744  0.110638
# 9801   0.708506 -0.845246 -0.463390
# 9816   0.528661 -0.852537 -0.355829
# 10107  0.756535 -0.561002 -0.675166
# 11085  0.373938 -0.978423 -0.210853
# 11883  0.429904 -0.514184 -0.199506
# 11902  0.386720 -0.302629 -0.435636
# 15736  0.510680 -0.258753 -0.396288
# 18812  0.553836 -0.826214 -0.188573

# %% [markdown]
# ### Merging clusters

# %% [markdown]
# In this step, we examine each of the groups obtained from KMeans clustering to see if any of the clusters can be merged. The authors proposed the following distance formula for calculating pairwise distances between the groups:
# <br><br>
# <div style="text-align: center;">
#     <i>
#         <strong>dis_K<sub>ij</sub> = dis_KC<sub>ij</sub> + (dis_r<sub>i</sub> - dis_r<sub>j</sub></strong>
#     </i>, where
#     <br><br>
#     <i><strong>dis_K<sub>ij</sub></strong></i> = distance between clusters <i>i</i> and <i>j</i>,
#     <br>
#     <i><strong>dis_KC<sub>ij</sub></strong></i> = distance between the cluster centers of clusters <i>i</i> and <i>j</i>,
#     <br>
#     <i><strong>dis_r<sub>i</sub></strong></i> = distance of the furthest point in cluster <i>i</i> to the corresponding center, and
#     <br>
#     <i><strong>dis_r<sub>j</sub></strong></i> = distance of the furthest point in cluster <i>j</i> to the corresponding center
# </div>

# %%
# We will be using the Euclidean distance
from scipy.spatial import distance

# %% [markdown]
# ##### Saving centers and farthest point of each cluster in a dictionary

# %%
km_centers = {}
farthest_point = {}

for i in range(0, num_clusters):
    # finding the center of cluster i
    label = "KC" + str(i)
    center = km_abalone.cluster_centers_[i]
    km_centers[label] = center
    
    # iterating through each sample in cluster i to find the farthest point
#     print(cluster_features[label].head())
    samples = cluster_features[label].drop(['db_clus'], axis=1).to_numpy() 
    max_dist = 0
#     print(samples.shape)
    for sample in samples:        
        dist = distance.euclidean(np.array(sample), center)
        if dist >= max_dist:
            farthest_point[label] = {"point": np.array(sample),"distance": dist}
            max_dist = dist

# %% [markdown]
# ##### Computing pairwise distances of each cluster using the distance formula defined earlier

# %%
pairwise_distance = np.full((num_clusters, num_clusters), np.inf)

for i in range(0, num_clusters):
    ci = "KC" + str(i) # label of cluster i
    
    for j in range(i + 1, num_clusters):
        cj = "KC" + str(j) # label of cluster j
        if i == j:
            pairwise_distance[i][j] = 0
        else:
            pairwise_distance[i][j] = distance.euclidean(km_centers[ci], km_centers[cj]) 
            + (farthest_point[ci]["distance"] - farthest_point[cj]["distance"])
pairwise_distance

# utility function that returns the pairwise distance of two groups
def pair_dist_group(i, j):
    return pairwise_distance[i][j]

# %%
# scratchpad
s = '2'
type(int(s))
# Out:
# int

# %%
# cluster_samples - contains list of KMeans groups
# dbscan_clusters - contains dbscan clusters for each KMeans group

counter = 1
flag = {}
flag_ref = {}
k = num_clusters # number of kmeans groups
epsilon = 3.0 # distance above which clusters will be pruned
MinPts = 4

# temp = []

for a in range(k-1):
    label_k1 = "KC" + str(a)
    num_1 = len(dbscan_clusters[label_k1]) # # of dbscan clusters in group a
    for b in range(k):
        label_k2 = "KC" + str(b)
        num_2 = len(dbscan_clusters[label_k2]) # of dbscan clusters in group b
        print("num1, num2 => ", num_1, num_2)
        dis_k = pair_dist_group(a, b)
#         print("Distance between ", label_k1, " and ", label_k2, " = ", dis_k)
        if dis_k <= epsilon:
            print("Nearby clusters - look at merging ", label_k1, " and ", label_k2)
            print("#, dbscan clusters in ", label_k1, " = ", num_1)
            print("#, dbscan clusters in ", label_k2, " = ", num_2)
            group1 = dbscan_clusters[label_k1]
            group2 = dbscan_clusters[label_k2]
            if num_1 > 0 and num_2 > 0:
                for c in group1.keys():
                    cluster1 = group1[c]
                    for d in group2.keys():                        
                        cluster2 = group2[d]
                        print("Checking cluster ", c, " of ", label_k1, " and cluster ", d, " of ", label_k2)
                        dis_db = minC_distance(cluster1, cluster2)
                        print("dis_db ---> ", dis_db)
                        
                        # converting all keys to integers
                        int_a = int(a)
                        int_b = int(b)
                        int_c = int(c)
                        int_d = int(d)
                        
                        if dis_db <= epsilon:
                            if(int_a, int_c) not in flag and (int_b, int_d) not in flag:
                                flag[(int_a, int_c)] = counter
                                flag[(int_b, int_d)] = counter
                                flag_ref[('a_'+str(int_a), 'c_'+str(int_c))] = counter
                                flag_ref[('b_'+str(int_b), 'd_'+str(int_d))] = counter
                                counter += 1
                            else:
                                flag[(int_a, int_c)] = max(flag.get((int_a, int_c), 0), flag.get((int_b, int_d), 0))
                                flag[(int_b, int_d)] = max(flag.get((int_a, int_c), 0), flag.get((int_b, int_d), 0))
                                flag_ref[('a_'+str(int_a), 'c_'+str(int_c))] = max(flag.get((int_a, int_c), 0), flag.get((int_b, int_d), 0))
                                flag_ref[('b_'+str(int_b), 'd_'+str(int_d))] = max(flag.get((int_a, int_c), 0), flag.get((int_b, int_d), 0))
    print("\n")
# Out:
# num1, num2 =>  3 3
# num1, num2 =>  3 1
# Nearby clusters - look at merging  KC0  and  KC1
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC1  =  1
# Checking cluster  0  of  KC0  and cluster  0  of  KC1
# dis_db --->  1.1633469199566409
# Checking cluster  1  of  KC0  and cluster  0  of  KC1
# dis_db --->  1.4879869052009627
# Checking cluster  2  of  KC0  and cluster  0  of  KC1
# dis_db --->  2.043599107564572
# num1, num2 =>  3 2
# num1, num2 =>  3 0
# num1, num2 =>  3 0
# num1, num2 =>  3 1
# Nearby clusters - look at merging  KC0  and  KC5
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC5  =  1
# Checking cluster  0  of  KC0  and cluster  0  of  KC5
# dis_db --->  0.47594103642366564
# Checking cluster  1  of  KC0  and cluster  0  of  KC5
# dis_db --->  1.2508644092774706
# Checking cluster  2  of  KC0  and cluster  0  of  KC5
# dis_db --->  1.0621750180843859
# num1, num2 =>  3 1
# Nearby clusters - look at merging  KC0  and  KC6
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC6  =  1
# Checking cluster  0  of  KC0  and cluster  0  of  KC6
# dis_db --->  1.481293146699219
# Checking cluster  1  of  KC0  and cluster  0  of  KC6
# dis_db --->  1.9743849332967598
# Checking cluster  2  of  KC0  and cluster  0  of  KC6
# dis_db --->  1.6494562924752971
# num1, num2 =>  3 2
# num1, num2 =>  3 0
# num1, num2 =>  3 0
# num1, num2 =>  3 2
# Nearby clusters - look at merging  KC0  and  KC10
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC10  =  2
# Checking cluster  0  of  KC0  and cluster  0  of  KC10
# dis_db --->  1.2456564028678239
# Checking cluster  0  of  KC0  and cluster  1  of  KC10
# dis_db --->  1.3690558518625429
# Checking cluster  1  of  KC0  and cluster  0  of  KC10
# dis_db --->  1.5866264121931806
# Checking cluster  1  of  KC0  and cluster  1  of  KC10
# dis_db --->  1.7445150261839695
# Checking cluster  2  of  KC0  and cluster  0  of  KC10
# dis_db --->  2.0389922414113477
# Checking cluster  2  of  KC0  and cluster  1  of  KC10
# dis_db --->  2.2380976929959
# num1, num2 =>  3 0
# num1, num2 =>  3 0
# Nearby clusters - look at merging  KC0  and  KC12
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC12  =  0
# num1, num2 =>  3 1
# Nearby clusters - look at merging  KC0  and  KC13
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC13  =  1
# Checking cluster  0  of  KC0  and cluster  0  of  KC13
# dis_db --->  0.3976000401325964
# Checking cluster  1  of  KC0  and cluster  0  of  KC13
# dis_db --->  0.72611669468261
# Checking cluster  2  of  KC0  and cluster  0  of  KC13
# dis_db --->  0.7983266314606735
# num1, num2 =>  3 0
# num1, num2 =>  3 8
# num1, num2 =>  3 1
# num1, num2 =>  3 0
# num1, num2 =>  3 1
# Nearby clusters - look at merging  KC0  and  KC18
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC18  =  1
# Checking cluster  0  of  KC0  and cluster  0  of  KC18
# dis_db --->  2.479556021915883
# Checking cluster  1  of  KC0  and cluster  0  of  KC18
# dis_db --->  2.9193571598109944
# Checking cluster  2  of  KC0  and cluster  0  of  KC18
# dis_db --->  3.294624870105499
# num1, num2 =>  3 0
# num1, num2 =>  3 0
# num1, num2 =>  3 4
# num1, num2 =>  3 2
# Nearby clusters - look at merging  KC0  and  KC22
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC22  =  2
# Checking cluster  0  of  KC0  and cluster  0  of  KC22
# dis_db --->  0.7367715340976148
# Checking cluster  0  of  KC0  and cluster  1  of  KC22
# dis_db --->  1.6461748367960203
# Checking cluster  1  of  KC0  and cluster  0  of  KC22
# dis_db --->  0.8719351850423617
# Checking cluster  1  of  KC0  and cluster  1  of  KC22
# dis_db --->  1.9335349574446365
# Checking cluster  2  of  KC0  and cluster  0  of  KC22
# dis_db --->  1.136622437409132
# Checking cluster  2  of  KC0  and cluster  1  of  KC22
# dis_db --->  2.203412632311289
# num1, num2 =>  3 1
# Nearby clusters - look at merging  KC0  and  KC23
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC23  =  1
# Checking cluster  0  of  KC0  and cluster  0  of  KC23
# dis_db --->  0.34420935661491986
# Checking cluster  1  of  KC0  and cluster  0  of  KC23
# dis_db --->  0.46911300202784567
# Checking cluster  2  of  KC0  and cluster  0  of  KC23
# dis_db --->  0.4648312849706084
# num1, num2 =>  3 0
# num1, num2 =>  3 2
# Nearby clusters - look at merging  KC0  and  KC25
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC25  =  2
# Checking cluster  0  of  KC0  and cluster  0  of  KC25
# dis_db --->  0.49112365162495186
# Checking cluster  0  of  KC0  and cluster  1  of  KC25
# dis_db --->  1.061391910704884
# Checking cluster  1  of  KC0  and cluster  0  of  KC25
# dis_db --->  1.0596668520262753
# Checking cluster  1  of  KC0  and cluster  1  of  KC25
# dis_db --->  1.6600811164296903
# Checking cluster  2  of  KC0  and cluster  0  of  KC25
# dis_db --->  0.9597197890083797
# Checking cluster  2  of  KC0  and cluster  1  of  KC25
# dis_db --->  1.3999939045572651
# num1, num2 =>  3 0
# num1, num2 =>  3 0
# num1, num2 =>  3 0
# num1, num2 =>  3 0
# num1, num2 =>  3 1
# Nearby clusters - look at merging  KC0  and  KC30
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC30  =  1
# Checking cluster  0  of  KC0  and cluster  0  of  KC30
# dis_db --->  1.0452647606607646
# Checking cluster  1  of  KC0  and cluster  0  of  KC30
# dis_db --->  1.6403785139780562
# Checking cluster  2  of  KC0  and cluster  0  of  KC30
# dis_db --->  1.2419908183319317
# num1, num2 =>  3 2
# Nearby clusters - look at merging  KC0  and  KC31
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC31  =  2
# Checking cluster  0  of  KC0  and cluster  0  of  KC31
# dis_db --->  1.1682936459050968
# Checking cluster  0  of  KC0  and cluster  1  of  KC31
# dis_db --->  1.964062124538904
# Checking cluster  1  of  KC0  and cluster  0  of  KC31
# dis_db --->  1.8165513625365557
# Checking cluster  1  of  KC0  and cluster  1  of  KC31
# dis_db --->  2.4978882324053275
# Checking cluster  2  of  KC0  and cluster  0  of  KC31
# dis_db --->  1.892588665047883
# Checking cluster  2  of  KC0  and cluster  1  of  KC31
# dis_db --->  2.5573764419512277
# num1, num2 =>  3 2
# num1, num2 =>  3 0
# num1, num2 =>  3 0
# num1, num2 =>  3 0
# num1, num2 =>  3 0
# num1, num2 =>  3 0
# num1, num2 =>  3 2
# num1, num2 =>  3 2
# Nearby clusters - look at merging  KC0  and  KC39
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC39  =  2
# Checking cluster  0  of  KC0  and cluster  0  of  KC39
# dis_db --->  1.638403845515074
# Checking cluster  0  of  KC0  and cluster  1  of  KC39
# dis_db --->  2.605939084751317
# Checking cluster  1  of  KC0  and cluster  0  of  KC39
# dis_db --->  1.5379851179585735
# Checking cluster  1  of  KC0  and cluster  1  of  KC39
# dis_db --->  2.6305876738971854
# Checking cluster  2  of  KC0  and cluster  0  of  KC39
# dis_db --->  1.5657926102166289
# Checking cluster  2  of  KC0  and cluster  1  of  KC39
# dis_db --->  2.457173486963884
# num1, num2 =>  3 2
# Nearby clusters - look at merging  KC0  and  KC40
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC40  =  2
# Checking cluster  0  of  KC0  and cluster  0  of  KC40
# dis_db --->  1.0437221476888052
# Checking cluster  0  of  KC0  and cluster  1  of  KC40
# dis_db --->  1.2307171376808388
# Checking cluster  1  of  KC0  and cluster  0  of  KC40
# dis_db --->  1.46222940023312
# Checking cluster  1  of  KC0  and cluster  1  of  KC40
# dis_db --->  1.6152798831145432
# Checking cluster  2  of  KC0  and cluster  0  of  KC40
# dis_db --->  0.7406529159783732
# Checking cluster  2  of  KC0  and cluster  1  of  KC40
# dis_db --->  0.9633485516390378
# num1, num2 =>  3 0
# num1, num2 =>  3 1
# num1, num2 =>  3 2
# Nearby clusters - look at merging  KC0  and  KC43
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC43  =  2
# Checking cluster  0  of  KC0  and cluster  0  of  KC43
# dis_db --->  0.4397361041917289
# Checking cluster  0  of  KC0  and cluster  1  of  KC43
# dis_db --->  1.0865544773914289
# Checking cluster  1  of  KC0  and cluster  0  of  KC43
# dis_db --->  0.6560868157969745
# Checking cluster  1  of  KC0  and cluster  1  of  KC43
# dis_db --->  1.3309305769130193
# Checking cluster  2  of  KC0  and cluster  0  of  KC43
# dis_db --->  1.0507219172110553
# Checking cluster  2  of  KC0  and cluster  1  of  KC43
# dis_db --->  1.8594378084664123
# num1, num2 =>  3 1
# num1, num2 =>  3 1
# Nearby clusters - look at merging  KC0  and  KC45
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC45  =  1
# Checking cluster  0  of  KC0  and cluster  0  of  KC45
# dis_db --->  0.3119150958100548
# Checking cluster  1  of  KC0  and cluster  0  of  KC45
# dis_db --->  0.8968220305106839
# Checking cluster  2  of  KC0  and cluster  0  of  KC45
# dis_db --->  0.865632873454251
# num1, num2 =>  3 3
# Nearby clusters - look at merging  KC0  and  KC46
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC46  =  3
# Checking cluster  0  of  KC0  and cluster  0  of  KC46
# dis_db --->  1.1238213803556274
# Checking cluster  0  of  KC0  and cluster  1  of  KC46
# dis_db --->  1.5379817261243667
# Checking cluster  0  of  KC0  and cluster  2  of  KC46
# dis_db --->  1.4293112408798476
# Checking cluster  1  of  KC0  and cluster  0  of  KC46
# dis_db --->  1.5695737552128433
# Checking cluster  1  of  KC0  and cluster  1  of  KC46
# dis_db --->  2.0353970495323384
# Checking cluster  1  of  KC0  and cluster  2  of  KC46
# dis_db --->  1.667080880171665
# Checking cluster  2  of  KC0  and cluster  0  of  KC46
# dis_db --->  1.6043339812270807
# Checking cluster  2  of  KC0  and cluster  1  of  KC46
# dis_db --->  2.063300487088664
# Checking cluster  2  of  KC0  and cluster  2  of  KC46
# dis_db --->  1.9161042081388857
# num1, num2 =>  3 0
# num1, num2 =>  3 2
# Nearby clusters - look at merging  KC0  and  KC48
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC48  =  2
# Checking cluster  0  of  KC0  and cluster  0  of  KC48
# dis_db --->  0.8336424340719231
# Checking cluster  0  of  KC0  and cluster  1  of  KC48
# dis_db --->  0.8631234329853467
# Checking cluster  1  of  KC0  and cluster  0  of  KC48
# dis_db --->  1.14710755573107
# Checking cluster  1  of  KC0  and cluster  1  of  KC48
# dis_db --->  1.2513042258238305
# Checking cluster  2  of  KC0  and cluster  0  of  KC48
# dis_db --->  1.4714457672989356
# Checking cluster  2  of  KC0  and cluster  1  of  KC48
# dis_db --->  1.1788095390716153
# num1, num2 =>  3 1
# Nearby clusters - look at merging  KC0  and  KC49
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC49  =  1
# Checking cluster  0  of  KC0  and cluster  0  of  KC49
# dis_db --->  0.4104721934998352
# Checking cluster  1  of  KC0  and cluster  0  of  KC49
# dis_db --->  1.0358918239097537
# Checking cluster  2  of  KC0  and cluster  0  of  KC49
# dis_db --->  0.8687271547169608
# num1, num2 =>  3 4
# num1, num2 =>  3 6
# Nearby clusters - look at merging  KC0  and  KC51
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC51  =  6
# Checking cluster  0  of  KC0  and cluster  0  of  KC51
# dis_db --->  1.430520594551171
# Checking cluster  0  of  KC0  and cluster  1  of  KC51
# dis_db --->  1.4687873347336537
# Checking cluster  0  of  KC0  and cluster  2  of  KC51
# dis_db --->  1.5731421583873202
# Checking cluster  0  of  KC0  and cluster  3  of  KC51
# dis_db --->  1.7425563202045122
# Checking cluster  0  of  KC0  and cluster  4  of  KC51
# dis_db --->  1.603421314371194
# Checking cluster  0  of  KC0  and cluster  5  of  KC51
# dis_db --->  1.453203127552084
# Checking cluster  1  of  KC0  and cluster  0  of  KC51
# dis_db --->  1.6752693608521025
# Checking cluster  1  of  KC0  and cluster  1  of  KC51
# dis_db --->  1.7716114451776068
# Checking cluster  1  of  KC0  and cluster  2  of  KC51
# dis_db --->  2.0125317176488604
# Checking cluster  1  of  KC0  and cluster  3  of  KC51
# dis_db --->  2.021044209871958
# Checking cluster  1  of  KC0  and cluster  4  of  KC51
# dis_db --->  1.8177579085516582
# Checking cluster  1  of  KC0  and cluster  5  of  KC51
# dis_db --->  1.9284093585065991
# Checking cluster  2  of  KC0  and cluster  0  of  KC51
# dis_db --->  2.0597920173507327
# Checking cluster  2  of  KC0  and cluster  1  of  KC51
# dis_db --->  2.1258512874556996
# Checking cluster  2  of  KC0  and cluster  2  of  KC51
# dis_db --->  2.3667649703778117
# Checking cluster  2  of  KC0  and cluster  3  of  KC51
# dis_db --->  2.2604060011261295
# Checking cluster  2  of  KC0  and cluster  4  of  KC51
# dis_db --->  2.1309673160975975
# Checking cluster  2  of  KC0  and cluster  5  of  KC51
# dis_db --->  2.129318556595765
# num1, num2 =>  3 0
# num1, num2 =>  3 3
# num1, num2 =>  3 0
# num1, num2 =>  3 0
# num1, num2 =>  3 2
# Nearby clusters - look at merging  KC0  and  KC56
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC56  =  2
# Checking cluster  0  of  KC0  and cluster  0  of  KC56
# dis_db --->  0.9959919779658399
# Checking cluster  0  of  KC0  and cluster  1  of  KC56
# dis_db --->  0.8822400103515429
# Checking cluster  1  of  KC0  and cluster  0  of  KC56
# dis_db --->  0.8813429859375114
# Checking cluster  1  of  KC0  and cluster  1  of  KC56
# dis_db --->  0.9048177241518371
# Checking cluster  2  of  KC0  and cluster  0  of  KC56
# dis_db --->  0.977395846455387
# Checking cluster  2  of  KC0  and cluster  1  of  KC56
# dis_db --->  0.7199397789180176
# num1, num2 =>  3 2
# Nearby clusters - look at merging  KC0  and  KC57
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC57  =  2
# Checking cluster  0  of  KC0  and cluster  0  of  KC57
# dis_db --->  0.4519299680863043
# Checking cluster  0  of  KC0  and cluster  1  of  KC57
# dis_db --->  1.6024576687708132
# Checking cluster  1  of  KC0  and cluster  0  of  KC57
# dis_db --->  0.4994576155321905
# Checking cluster  1  of  KC0  and cluster  1  of  KC57
# dis_db --->  1.3967114252685426
# Checking cluster  2  of  KC0  and cluster  0  of  KC57
# dis_db --->  0.9886138627489535
# Checking cluster  2  of  KC0  and cluster  1  of  KC57
# dis_db --->  1.8007397979961004
# num1, num2 =>  3 5
# Nearby clusters - look at merging  KC0  and  KC58
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC58  =  5
# Checking cluster  0  of  KC0  and cluster  0  of  KC58
# dis_db --->  2.128297636257888
# Checking cluster  0  of  KC0  and cluster  1  of  KC58
# dis_db --->  1.912380442276429
# Checking cluster  0  of  KC0  and cluster  2  of  KC58
# dis_db --->  1.737425384437043
# Checking cluster  0  of  KC0  and cluster  3  of  KC58
# dis_db --->  2.093942314360667
# Checking cluster  0  of  KC0  and cluster  4  of  KC58
# dis_db --->  2.441244743522676
# Checking cluster  1  of  KC0  and cluster  0  of  KC58
# dis_db --->  2.465295787094952
# Checking cluster  1  of  KC0  and cluster  1  of  KC58
# dis_db --->  2.2665209109881927
# Checking cluster  1  of  KC0  and cluster  2  of  KC58
# dis_db --->  2.1300446321248163
# Checking cluster  1  of  KC0  and cluster  3  of  KC58
# dis_db --->  2.4513507713436313
# Checking cluster  1  of  KC0  and cluster  4  of  KC58
# dis_db --->  2.8798107408225495
# Checking cluster  2  of  KC0  and cluster  0  of  KC58
# dis_db --->  2.4277729864671866
# Checking cluster  2  of  KC0  and cluster  1  of  KC58
# dis_db --->  2.6239959493528473
# Checking cluster  2  of  KC0  and cluster  2  of  KC58
# dis_db --->  2.1811438740365694
# Checking cluster  2  of  KC0  and cluster  3  of  KC58
# dis_db --->  2.7237299985690586
# Checking cluster  2  of  KC0  and cluster  4  of  KC58
# dis_db --->  2.998051453744419
# num1, num2 =>  3 0
# num1, num2 =>  3 0
# num1, num2 =>  3 1
# num1, num2 =>  3 4
# Nearby clusters - look at merging  KC0  and  KC62
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC62  =  4
# Checking cluster  0  of  KC0  and cluster  0  of  KC62
# dis_db --->  1.8610499603575257
# Checking cluster  0  of  KC0  and cluster  1  of  KC62
# dis_db --->  2.7394961191764557
# Checking cluster  0  of  KC0  and cluster  2  of  KC62
# dis_db --->  2.430530401467945
# Checking cluster  0  of  KC0  and cluster  3  of  KC62
# dis_db --->  2.235493506133508
# Checking cluster  1  of  KC0  and cluster  0  of  KC62
# dis_db --->  1.8850661753337612
# Checking cluster  1  of  KC0  and cluster  1  of  KC62
# dis_db --->  2.6412935159117
# Checking cluster  1  of  KC0  and cluster  2  of  KC62
# dis_db --->  2.501995947473159
# Checking cluster  1  of  KC0  and cluster  3  of  KC62
# dis_db --->  2.3226843202449685
# Checking cluster  2  of  KC0  and cluster  0  of  KC62
# dis_db --->  2.491336690664947
# Checking cluster  2  of  KC0  and cluster  1  of  KC62
# dis_db --->  3.2611600570834467
# Checking cluster  2  of  KC0  and cluster  2  of  KC62
# dis_db --->  3.1106528125562978
# Checking cluster  2  of  KC0  and cluster  3  of  KC62
# dis_db --->  2.9598275376802126
# num1, num2 =>  3 1
# Nearby clusters - look at merging  KC0  and  KC63
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC63  =  1
# Checking cluster  0  of  KC0  and cluster  0  of  KC63
# dis_db --->  1.202674662636008
# Checking cluster  1  of  KC0  and cluster  0  of  KC63
# dis_db --->  1.2366068302465654
# Checking cluster  2  of  KC0  and cluster  0  of  KC63
# dis_db --->  0.9092375097955337
# num1, num2 =>  3 1
# num1, num2 =>  3 0
# num1, num2 =>  3 0
# num1, num2 =>  3 2
# Nearby clusters - look at merging  KC0  and  KC67
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC67  =  2
# Checking cluster  0  of  KC0  and cluster  0  of  KC67
# dis_db --->  0.48695491278543074
# Checking cluster  0  of  KC0  and cluster  1  of  KC67
# dis_db --->  0.4435679349383576
# Checking cluster  1  of  KC0  and cluster  0  of  KC67
# dis_db --->  0.8783601764717858
# Checking cluster  1  of  KC0  and cluster  1  of  KC67
# dis_db --->  1.1838695986239307
# Checking cluster  2  of  KC0  and cluster  0  of  KC67
# dis_db --->  1.3899693441284222
# Checking cluster  2  of  KC0  and cluster  1  of  KC67
# dis_db --->  1.6153184834453223
# num1, num2 =>  3 0
# num1, num2 =>  3 1
# Nearby clusters - look at merging  KC0  and  KC69
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC69  =  1
# Checking cluster  0  of  KC0  and cluster  0  of  KC69
# dis_db --->  0.6973081884014067
# Checking cluster  1  of  KC0  and cluster  0  of  KC69
# dis_db --->  1.1889278516873543
# Checking cluster  2  of  KC0  and cluster  0  of  KC69
# dis_db --->  1.7249786493781776
# num1, num2 =>  3 4
# num1, num2 =>  3 0
# num1, num2 =>  3 0
# num1, num2 =>  3 6
# Nearby clusters - look at merging  KC0  and  KC73
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC73  =  6
# Checking cluster  0  of  KC0  and cluster  0  of  KC73
# dis_db --->  2.524273832560551
# Checking cluster  0  of  KC0  and cluster  1  of  KC73
# dis_db --->  1.7781806134248557
# Checking cluster  0  of  KC0  and cluster  2  of  KC73
# dis_db --->  2.0644254815971332
# Checking cluster  0  of  KC0  and cluster  3  of  KC73
# dis_db --->  2.323358352048139
# Checking cluster  0  of  KC0  and cluster  4  of  KC73
# dis_db --->  2.7689562044579246
# Checking cluster  0  of  KC0  and cluster  5  of  KC73
# dis_db --->  2.0542220800685547
# Checking cluster  1  of  KC0  and cluster  0  of  KC73
# dis_db --->  2.489796077287105
# Checking cluster  1  of  KC0  and cluster  1  of  KC73
# dis_db --->  1.7063571204560986
# Checking cluster  1  of  KC0  and cluster  2  of  KC73
# dis_db --->  1.9348169737450451
# Checking cluster  1  of  KC0  and cluster  3  of  KC73
# dis_db --->  2.1804842987667477
# Checking cluster  1  of  KC0  and cluster  4  of  KC73
# dis_db --->  2.7995544299218325
# Checking cluster  1  of  KC0  and cluster  5  of  KC73
# dis_db --->  1.8354133146627565
# Checking cluster  2  of  KC0  and cluster  0  of  KC73
# dis_db --->  2.8464104192310584
# Checking cluster  2  of  KC0  and cluster  1  of  KC73
# dis_db --->  1.9066313767085543
# Checking cluster  2  of  KC0  and cluster  2  of  KC73
# dis_db --->  2.374112837957741
# Checking cluster  2  of  KC0  and cluster  3  of  KC73
# dis_db --->  2.817398832962511
# Checking cluster  2  of  KC0  and cluster  4  of  KC73
# dis_db --->  3.087329421325785
# Checking cluster  2  of  KC0  and cluster  5  of  KC73
# dis_db --->  2.3268890645907936
# num1, num2 =>  3 2
# Nearby clusters - look at merging  KC0  and  KC74
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC74  =  2
# Checking cluster  0  of  KC0  and cluster  0  of  KC74
# dis_db --->  2.0157622181268806
# Checking cluster  0  of  KC0  and cluster  1  of  KC74
# dis_db --->  2.228924230099875
# Checking cluster  1  of  KC0  and cluster  0  of  KC74
# dis_db --->  2.3598398599254384
# Checking cluster  1  of  KC0  and cluster  1  of  KC74
# dis_db --->  2.466724643858097
# Checking cluster  2  of  KC0  and cluster  0  of  KC74
# dis_db --->  2.478519289410284
# Checking cluster  2  of  KC0  and cluster  1  of  KC74
# dis_db --->  2.6826760938990932
# num1, num2 =>  3 0
# num1, num2 =>  3 0
# num1, num2 =>  3 1
# Nearby clusters - look at merging  KC0  and  KC77
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC77  =  1
# Checking cluster  0  of  KC0  and cluster  0  of  KC77
# dis_db --->  0.7800673951368327
# Checking cluster  1  of  KC0  and cluster  0  of  KC77
# dis_db --->  0.5982371929591843
# Checking cluster  2  of  KC0  and cluster  0  of  KC77
# dis_db --->  0.4143603527059257
# num1, num2 =>  3 3
# Nearby clusters - look at merging  KC0  and  KC78
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC78  =  3
# Checking cluster  0  of  KC0  and cluster  0  of  KC78
# dis_db --->  0.980326631623469
# Checking cluster  0  of  KC0  and cluster  1  of  KC78
# dis_db --->  0.8816660320686219
# Checking cluster  0  of  KC0  and cluster  2  of  KC78
# dis_db --->  1.5427870979547538
# Checking cluster  1  of  KC0  and cluster  0  of  KC78
# dis_db --->  1.3225105354829567
# Checking cluster  1  of  KC0  and cluster  1  of  KC78
# dis_db --->  1.5617449049648682
# Checking cluster  1  of  KC0  and cluster  2  of  KC78
# dis_db --->  1.3872639649648422
# Checking cluster  2  of  KC0  and cluster  0  of  KC78
# dis_db --->  1.5485797613246681
# Checking cluster  2  of  KC0  and cluster  1  of  KC78
# dis_db --->  1.5882402835295997
# Checking cluster  2  of  KC0  and cluster  2  of  KC78
# dis_db --->  1.8925813259409126
# num1, num2 =>  3 0
# num1, num2 =>  3 3
# Nearby clusters - look at merging  KC0  and  KC80
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC80  =  3
# Checking cluster  0  of  KC0  and cluster  0  of  KC80
# dis_db --->  1.0420815398942445
# Checking cluster  0  of  KC0  and cluster  1  of  KC80
# dis_db --->  2.0839413144819123
# Checking cluster  0  of  KC0  and cluster  2  of  KC80
# dis_db --->  2.1635268095377675
# Checking cluster  1  of  KC0  and cluster  0  of  KC80
# dis_db --->  1.6606180354721924
# Checking cluster  1  of  KC0  and cluster  1  of  KC80
# dis_db --->  2.5666152909266606
# Checking cluster  1  of  KC0  and cluster  2  of  KC80
# dis_db --->  2.8852510542176932
# Checking cluster  2  of  KC0  and cluster  0  of  KC80
# dis_db --->  1.5073116274319547
# Checking cluster  2  of  KC0  and cluster  1  of  KC80
# dis_db --->  2.4442933237675266
# Checking cluster  2  of  KC0  and cluster  2  of  KC80
# dis_db --->  2.6889682245222835
# num1, num2 =>  3 1
# Nearby clusters - look at merging  KC0  and  KC81
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC81  =  1
# Checking cluster  0  of  KC0  and cluster  0  of  KC81
# dis_db --->  0.4715530116342634
# Checking cluster  1  of  KC0  and cluster  0  of  KC81
# dis_db --->  0.7753460987048368
# Checking cluster  2  of  KC0  and cluster  0  of  KC81
# dis_db --->  1.1228316683021446
# num1, num2 =>  3 0
# num1, num2 =>  3 4
# Nearby clusters - look at merging  KC0  and  KC83
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC83  =  4
# Checking cluster  0  of  KC0  and cluster  0  of  KC83
# dis_db --->  1.1633146901440987
# Checking cluster  0  of  KC0  and cluster  1  of  KC83
# dis_db --->  1.2993498366398815
# Checking cluster  0  of  KC0  and cluster  2  of  KC83
# dis_db --->  1.281890978281236
# Checking cluster  0  of  KC0  and cluster  3  of  KC83
# dis_db --->  1.3557059483901943
# Checking cluster  1  of  KC0  and cluster  0  of  KC83
# dis_db --->  0.7987241884693462
# Checking cluster  1  of  KC0  and cluster  1  of  KC83
# dis_db --->  1.2050579802606693
# Checking cluster  1  of  KC0  and cluster  2  of  KC83
# dis_db --->  0.9684377289443841
# Checking cluster  1  of  KC0  and cluster  3  of  KC83
# dis_db --->  0.9880619574665871
# Checking cluster  2  of  KC0  and cluster  0  of  KC83
# dis_db --->  1.2258061829315088
# Checking cluster  2  of  KC0  and cluster  1  of  KC83
# dis_db --->  1.6779132647513733
# Checking cluster  2  of  KC0  and cluster  2  of  KC83
# dis_db --->  1.2485173345033083
# Checking cluster  2  of  KC0  and cluster  3  of  KC83
# dis_db --->  1.3171231904734837
# num1, num2 =>  3 0
# num1, num2 =>  3 0
# num1, num2 =>  3 0
# num1, num2 =>  3 0
# num1, num2 =>  3 1
# Nearby clusters - look at merging  KC0  and  KC88
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC88  =  1
# Checking cluster  0  of  KC0  and cluster  0  of  KC88
# dis_db --->  0.5145686169235119
# Checking cluster  1  of  KC0  and cluster  0  of  KC88
# dis_db --->  0.7912686199327525
# Checking cluster  2  of  KC0  and cluster  0  of  KC88
# dis_db --->  0.7200525355456334
# num1, num2 =>  3 0
# Nearby clusters - look at merging  KC0  and  KC89
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC89  =  0
# num1, num2 =>  3 2
# Nearby clusters - look at merging  KC0  and  KC90
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC90  =  2
# Checking cluster  0  of  KC0  and cluster  0  of  KC90
# dis_db --->  1.333732835378586
# Checking cluster  0  of  KC0  and cluster  1  of  KC90
# dis_db --->  2.354701104868966
# Checking cluster  1  of  KC0  and cluster  0  of  KC90
# dis_db --->  1.5639155937856275
# Checking cluster  1  of  KC0  and cluster  1  of  KC90
# dis_db --->  2.3758690630108497
# Checking cluster  2  of  KC0  and cluster  0  of  KC90
# dis_db --->  1.1324384685274131
# Checking cluster  2  of  KC0  and cluster  1  of  KC90
# dis_db --->  2.031278632712166
# num1, num2 =>  3 1
# Nearby clusters - look at merging  KC0  and  KC91
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC91  =  1
# Checking cluster  0  of  KC0  and cluster  0  of  KC91
# dis_db --->  1.4793549008941678
# Checking cluster  1  of  KC0  and cluster  0  of  KC91
# dis_db --->  1.6185012379202148
# Checking cluster  2  of  KC0  and cluster  0  of  KC91
# dis_db --->  2.2894497624989776
# num1, num2 =>  3 6
# num1, num2 =>  3 0
# num1, num2 =>  3 1
# Nearby clusters - look at merging  KC0  and  KC94
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC94  =  1
# Checking cluster  0  of  KC0  and cluster  0  of  KC94
# dis_db --->  0.5971685123254031
# Checking cluster  1  of  KC0  and cluster  0  of  KC94
# dis_db --->  0.5184857429491381
# Checking cluster  2  of  KC0  and cluster  0  of  KC94
# dis_db --->  0.5741112183793889
# num1, num2 =>  3 1
# Nearby clusters - look at merging  KC0  and  KC95
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC95  =  1
# Checking cluster  0  of  KC0  and cluster  0  of  KC95
# dis_db --->  1.194848742237817
# Checking cluster  1  of  KC0  and cluster  0  of  KC95
# dis_db --->  1.4510438695867327
# Checking cluster  2  of  KC0  and cluster  0  of  KC95
# dis_db --->  1.24690288096093
# num1, num2 =>  3 0
# num1, num2 =>  3 2
# Nearby clusters - look at merging  KC0  and  KC97
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC97  =  2
# Checking cluster  0  of  KC0  and cluster  0  of  KC97
# dis_db --->  0.5757704183167981
# Checking cluster  0  of  KC0  and cluster  1  of  KC97
# dis_db --->  1.6180386129969098
# Checking cluster  1  of  KC0  and cluster  0  of  KC97
# dis_db --->  0.44062774439191166
# Checking cluster  1  of  KC0  and cluster  1  of  KC97
# dis_db --->  1.466338237079593
# Checking cluster  2  of  KC0  and cluster  0  of  KC97
# dis_db --->  0.6498828139096605
# Checking cluster  2  of  KC0  and cluster  1  of  KC97
# dis_db --->  1.558265528225261
# num1, num2 =>  3 0
# num1, num2 =>  3 0
# num1, num2 =>  3 3
# Nearby clusters - look at merging  KC0  and  KC100
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC100  =  3
# Checking cluster  0  of  KC0  and cluster  0  of  KC100
# dis_db --->  0.5871446308539557
# Checking cluster  0  of  KC0  and cluster  1  of  KC100
# dis_db --->  0.9821945521540255
# Checking cluster  0  of  KC0  and cluster  2  of  KC100
# dis_db --->  1.641652036387728
# Checking cluster  1  of  KC0  and cluster  0  of  KC100
# dis_db --->  0.897400234733179
# Checking cluster  1  of  KC0  and cluster  1  of  KC100
# dis_db --->  1.2963871977588846
# Checking cluster  1  of  KC0  and cluster  2  of  KC100
# dis_db --->  1.9603075468837758
# Checking cluster  2  of  KC0  and cluster  0  of  KC100
# dis_db --->  1.240509582864766
# Checking cluster  2  of  KC0  and cluster  1  of  KC100
# dis_db --->  1.5373246478654172
# Checking cluster  2  of  KC0  and cluster  2  of  KC100
# dis_db --->  2.2246567356744102
# num1, num2 =>  3 0
# num1, num2 =>  3 1
# Nearby clusters - look at merging  KC0  and  KC102
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC102  =  1
# Checking cluster  0  of  KC0  and cluster  0  of  KC102
# dis_db --->  0.46652981847102526
# Checking cluster  1  of  KC0  and cluster  0  of  KC102
# dis_db --->  1.008579796651068
# Checking cluster  2  of  KC0  and cluster  0  of  KC102
# dis_db --->  0.6293761783537584
# num1, num2 =>  3 0
# num1, num2 =>  3 0
# num1, num2 =>  3 1
# Nearby clusters - look at merging  KC0  and  KC105
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC105  =  1
# Checking cluster  0  of  KC0  and cluster  0  of  KC105
# dis_db --->  0.3240221689904128
# Checking cluster  1  of  KC0  and cluster  0  of  KC105
# dis_db --->  0.7126385957273529
# Checking cluster  2  of  KC0  and cluster  0  of  KC105
# dis_db --->  1.0024611240916477
# num1, num2 =>  3 0
# Nearby clusters - look at merging  KC0  and  KC106
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC106  =  0
# num1, num2 =>  3 0
# num1, num2 =>  3 0
# num1, num2 =>  3 2
# Nearby clusters - look at merging  KC0  and  KC109
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC109  =  2
# Checking cluster  0  of  KC0  and cluster  0  of  KC109
# dis_db --->  0.9406304821028328
# Checking cluster  0  of  KC0  and cluster  1  of  KC109
# dis_db --->  1.477357036291359
# Checking cluster  1  of  KC0  and cluster  0  of  KC109
# dis_db --->  1.4401419523525554
# Checking cluster  1  of  KC0  and cluster  1  of  KC109
# dis_db --->  1.9058768363665008
# Checking cluster  2  of  KC0  and cluster  0  of  KC109
# dis_db --->  1.4746476433458253
# Checking cluster  2  of  KC0  and cluster  1  of  KC109
# dis_db --->  2.050766995556212
# num1, num2 =>  3 2
# Nearby clusters - look at merging  KC0  and  KC110
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC110  =  2
# Checking cluster  0  of  KC0  and cluster  0  of  KC110
# dis_db --->  0.9889648018230697
# Checking cluster  0  of  KC0  and cluster  1  of  KC110
# dis_db --->  1.0885030358878036
# Checking cluster  1  of  KC0  and cluster  0  of  KC110
# dis_db --->  0.9301023341464363
# Checking cluster  1  of  KC0  and cluster  1  of  KC110
# dis_db --->  1.1927853703220281
# Checking cluster  2  of  KC0  and cluster  0  of  KC110
# dis_db --->  0.8610246750146204
# Checking cluster  2  of  KC0  and cluster  1  of  KC110
# dis_db --->  0.8409060876536838
# num1, num2 =>  3 0
# num1, num2 =>  3 1
# num1, num2 =>  3 2
# Nearby clusters - look at merging  KC0  and  KC113
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC113  =  2
# Checking cluster  0  of  KC0  and cluster  0  of  KC113
# dis_db --->  1.0884988377710803
# Checking cluster  0  of  KC0  and cluster  1  of  KC113
# dis_db --->  1.3240084684029625
# Checking cluster  1  of  KC0  and cluster  0  of  KC113
# dis_db --->  1.0553449050322248
# Checking cluster  1  of  KC0  and cluster  1  of  KC113
# dis_db --->  1.5363287222289832
# Checking cluster  2  of  KC0  and cluster  0  of  KC113
# dis_db --->  1.5966074444447629
# Checking cluster  2  of  KC0  and cluster  1  of  KC113
# dis_db --->  1.923475655980219
# num1, num2 =>  3 4
# num1, num2 =>  3 0
# num1, num2 =>  3 2
# num1, num2 =>  3 2
# Nearby clusters - look at merging  KC0  and  KC117
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC117  =  2
# Checking cluster  0  of  KC0  and cluster  0  of  KC117
# dis_db --->  1.4361697417060837
# Checking cluster  0  of  KC0  and cluster  1  of  KC117
# dis_db --->  1.6262260321116109
# Checking cluster  1  of  KC0  and cluster  0  of  KC117
# dis_db --->  1.7177765207824878
# Checking cluster  1  of  KC0  and cluster  1  of  KC117
# dis_db --->  1.9564323618003543
# Checking cluster  2  of  KC0  and cluster  0  of  KC117
# dis_db --->  2.1650223549052465
# Checking cluster  2  of  KC0  and cluster  1  of  KC117
# dis_db --->  2.51722184148382
# num1, num2 =>  3 0
# num1, num2 =>  3 1
# num1, num2 =>  3 1
# num1, num2 =>  3 4
# Nearby clusters - look at merging  KC0  and  KC121
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC121  =  4
# Checking cluster  0  of  KC0  and cluster  0  of  KC121
# dis_db --->  2.413160290229969
# Checking cluster  0  of  KC0  and cluster  1  of  KC121
# dis_db --->  2.4221326687415
# Checking cluster  0  of  KC0  and cluster  2  of  KC121
# dis_db --->  1.4858030244164833
# Checking cluster  0  of  KC0  and cluster  3  of  KC121
# dis_db --->  2.058283272389691
# Checking cluster  1  of  KC0  and cluster  0  of  KC121
# dis_db --->  2.9266387511383027
# Checking cluster  1  of  KC0  and cluster  1  of  KC121
# dis_db --->  2.4492051535895243
# Checking cluster  1  of  KC0  and cluster  2  of  KC121
# dis_db --->  1.9294149610905982
# Checking cluster  1  of  KC0  and cluster  3  of  KC121
# dis_db --->  2.351741952043338
# Checking cluster  2  of  KC0  and cluster  0  of  KC121
# dis_db --->  2.6181900719255955
# Checking cluster  2  of  KC0  and cluster  1  of  KC121
# dis_db --->  2.361437440036583
# Checking cluster  2  of  KC0  and cluster  2  of  KC121
# dis_db --->  1.7686709558857487
# Checking cluster  2  of  KC0  and cluster  3  of  KC121
# dis_db --->  2.4065890220766186
# num1, num2 =>  3 2
# Nearby clusters - look at merging  KC0  and  KC122
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC122  =  2
# Checking cluster  0  of  KC0  and cluster  0  of  KC122
# dis_db --->  1.16963692775544
# Checking cluster  0  of  KC0  and cluster  1  of  KC122
# dis_db --->  2.297350417740253
# Checking cluster  1  of  KC0  and cluster  0  of  KC122
# dis_db --->  1.9662406901326417
# Checking cluster  1  of  KC0  and cluster  1  of  KC122
# dis_db --->  2.9984421365060765
# Checking cluster  2  of  KC0  and cluster  0  of  KC122
# dis_db --->  1.5472954718208063
# Checking cluster  2  of  KC0  and cluster  1  of  KC122
# dis_db --->  2.518480684764764
# num1, num2 =>  3 0
# num1, num2 =>  3 1
# Nearby clusters - look at merging  KC0  and  KC124
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC124  =  1
# Checking cluster  0  of  KC0  and cluster  0  of  KC124
# dis_db --->  1.738136355125411
# Checking cluster  1  of  KC0  and cluster  0  of  KC124
# dis_db --->  1.883401066046401
# Checking cluster  2  of  KC0  and cluster  0  of  KC124
# dis_db --->  1.3467557782377284
# num1, num2 =>  3 0
# num1, num2 =>  3 0
# num1, num2 =>  3 1
# Nearby clusters - look at merging  KC0  and  KC127
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC127  =  1
# Checking cluster  0  of  KC0  and cluster  0  of  KC127
# dis_db --->  0.7591418223076049
# Checking cluster  1  of  KC0  and cluster  0  of  KC127
# dis_db --->  0.7907278721053814
# Checking cluster  2  of  KC0  and cluster  0  of  KC127
# dis_db --->  0.45402806467373474
# num1, num2 =>  3 1
# Nearby clusters - look at merging  KC0  and  KC128
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC128  =  1
# Checking cluster  0  of  KC0  and cluster  0  of  KC128
# dis_db --->  0.48734563210662557
# Checking cluster  1  of  KC0  and cluster  0  of  KC128
# dis_db --->  0.9000596349538976
# Checking cluster  2  of  KC0  and cluster  0  of  KC128
# dis_db --->  1.0865973268253006
# num1, num2 =>  3 0
# num1, num2 =>  3 0
# num1, num2 =>  3 2
# Nearby clusters - look at merging  KC0  and  KC131
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC131  =  2
# Checking cluster  0  of  KC0  and cluster  0  of  KC131
# dis_db --->  1.7026758948073792
# Checking cluster  0  of  KC0  and cluster  1  of  KC131
# dis_db --->  2.7349002474580737
# Checking cluster  1  of  KC0  and cluster  0  of  KC131
# dis_db --->  1.883073586124561
# Checking cluster  1  of  KC0  and cluster  1  of  KC131
# dis_db --->  3.007315188440844
# Checking cluster  2  of  KC0  and cluster  0  of  KC131
# dis_db --->  2.391279599627334
# Checking cluster  2  of  KC0  and cluster  1  of  KC131
# dis_db --->  3.234582005848092
# num1, num2 =>  3 0
# num1, num2 =>  3 1
# Nearby clusters - look at merging  KC0  and  KC133
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC133  =  1
# Checking cluster  0  of  KC0  and cluster  0  of  KC133
# dis_db --->  1.840807970818966
# Checking cluster  1  of  KC0  and cluster  0  of  KC133
# dis_db --->  2.161389134339655
# Checking cluster  2  of  KC0  and cluster  0  of  KC133
# dis_db --->  2.4087674268503076
# num1, num2 =>  3 1
# Nearby clusters - look at merging  KC0  and  KC134
# #, dbscan clusters in  KC0  =  3
# #, dbscan clusters in  KC134  =  1
# Checking cluster  0  of  KC0  and cluster  0  of  KC134
# dis_db --->  1.1175054330643417
# Checking cluster  1  of  KC0  and cluster  0  of  KC134
# dis_db --->  1.3221668506101385
# Checking cluster  2  of  KC0  and cluster  0  of  KC134
# dis_db --->  1.7677012440742228
# num1, num2 =>  3 4
# num1, num2 =>  3 0
#
#
# num1, num2 =>  1 3
# num1, num2 =>  1 1
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# Nearby clusters - look at merging  KC1  and  KC5
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC5  =  1
# Checking cluster  0  of  KC1  and cluster  0  of  KC5
# dis_db --->  0.7056006276608144
# num1, num2 =>  1 1
# num1, num2 =>  1 2
# Nearby clusters - look at merging  KC1  and  KC7
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC7  =  2
# Checking cluster  0  of  KC1  and cluster  0  of  KC7
# dis_db --->  1.2827045807232365
# Checking cluster  0  of  KC1  and cluster  1  of  KC7
# dis_db --->  1.8636209749884602
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# Nearby clusters - look at merging  KC1  and  KC10
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC10  =  2
# Checking cluster  0  of  KC1  and cluster  0  of  KC10
# dis_db --->  0.4307482548290564
# Checking cluster  0  of  KC1  and cluster  1  of  KC10
# dis_db --->  0.9526300851824515
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# Nearby clusters - look at merging  KC1  and  KC13
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC13  =  1
# Checking cluster  0  of  KC1  and cluster  0  of  KC13
# dis_db --->  1.2546457339704988
# num1, num2 =>  1 0
# num1, num2 =>  1 8
# Nearby clusters - look at merging  KC1  and  KC15
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC15  =  8
# Checking cluster  0  of  KC1  and cluster  0  of  KC15
# dis_db --->  1.577333003366232
# Checking cluster  0  of  KC1  and cluster  1  of  KC15
# dis_db --->  1.351544090006188
# Checking cluster  0  of  KC1  and cluster  2  of  KC15
# dis_db --->  2.364902455205393
# Checking cluster  0  of  KC1  and cluster  3  of  KC15
# dis_db --->  2.335332798251296
# Checking cluster  0  of  KC1  and cluster  4  of  KC15
# dis_db --->  1.7284955818325756
# Checking cluster  0  of  KC1  and cluster  5  of  KC15
# dis_db --->  1.8252810239190653
# Checking cluster  0  of  KC1  and cluster  6  of  KC15
# dis_db --->  2.408670064016098
# Checking cluster  0  of  KC1  and cluster  7  of  KC15
# dis_db --->  2.5427024684848583
# num1, num2 =>  1 1
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# Nearby clusters - look at merging  KC1  and  KC18
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC18  =  1
# Checking cluster  0  of  KC1  and cluster  0  of  KC18
# dis_db --->  2.0354385370032113
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 4
# Nearby clusters - look at merging  KC1  and  KC21
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC21  =  4
# Checking cluster  0  of  KC1  and cluster  0  of  KC21
# dis_db --->  0.4902974094822123
# Checking cluster  0  of  KC1  and cluster  1  of  KC21
# dis_db --->  0.9481502929969339
# Checking cluster  0  of  KC1  and cluster  2  of  KC21
# dis_db --->  0.9637055427287985
# Checking cluster  0  of  KC1  and cluster  3  of  KC21
# dis_db --->  1.3832525221027188
# num1, num2 =>  1 2
# Nearby clusters - look at merging  KC1  and  KC22
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC22  =  2
# Checking cluster  0  of  KC1  and cluster  0  of  KC22
# dis_db --->  0.34965606633256696
# Checking cluster  0  of  KC1  and cluster  1  of  KC22
# dis_db --->  0.9242649881078051
# num1, num2 =>  1 1
# Nearby clusters - look at merging  KC1  and  KC23
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC23  =  1
# Checking cluster  0  of  KC1  and cluster  0  of  KC23
# dis_db --->  1.1541193256017295
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# Nearby clusters - look at merging  KC1  and  KC25
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC25  =  2
# Checking cluster  0  of  KC1  and cluster  0  of  KC25
# dis_db --->  1.3544040707256642
# Checking cluster  0  of  KC1  and cluster  1  of  KC25
# dis_db --->  2.2240628387907857
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 2
# Nearby clusters - look at merging  KC1  and  KC31
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC31  =  2
# Checking cluster  0  of  KC1  and cluster  0  of  KC31
# dis_db --->  0.9908856385129233
# Checking cluster  0  of  KC1  and cluster  1  of  KC31
# dis_db --->  1.3564417619443512
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# Nearby clusters - look at merging  KC1  and  KC38
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC38  =  2
# Checking cluster  0  of  KC1  and cluster  0  of  KC38
# dis_db --->  1.3821462502746547
# Checking cluster  0  of  KC1  and cluster  1  of  KC38
# dis_db --->  2.750287566334155
# num1, num2 =>  1 2
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 2
# Nearby clusters - look at merging  KC1  and  KC43
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC43  =  2
# Checking cluster  0  of  KC1  and cluster  0  of  KC43
# dis_db --->  0.39223870060443083
# Checking cluster  0  of  KC1  and cluster  1  of  KC43
# dis_db --->  0.5592700548442959
# num1, num2 =>  1 1
# Nearby clusters - look at merging  KC1  and  KC44
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC44  =  1
# Checking cluster  0  of  KC1  and cluster  0  of  KC44
# dis_db --->  1.0291285595187056
# num1, num2 =>  1 1
# Nearby clusters - look at merging  KC1  and  KC45
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC45  =  1
# Checking cluster  0  of  KC1  and cluster  0  of  KC45
# dis_db --->  0.3226541160366147
# num1, num2 =>  1 3
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# Nearby clusters - look at merging  KC1  and  KC48
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC48  =  2
# Checking cluster  0  of  KC1  and cluster  0  of  KC48
# dis_db --->  2.287094955636389
# Checking cluster  0  of  KC1  and cluster  1  of  KC48
# dis_db --->  2.251651255566328
# num1, num2 =>  1 1
# Nearby clusters - look at merging  KC1  and  KC49
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC49  =  1
# Checking cluster  0  of  KC1  and cluster  0  of  KC49
# dis_db --->  1.467164288922164
# num1, num2 =>  1 4
# num1, num2 =>  1 6
# Nearby clusters - look at merging  KC1  and  KC51
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC51  =  6
# Checking cluster  0  of  KC1  and cluster  0  of  KC51
# dis_db --->  0.9955836927887277
# Checking cluster  0  of  KC1  and cluster  1  of  KC51
# dis_db --->  0.5978664906979602
# Checking cluster  0  of  KC1  and cluster  2  of  KC51
# dis_db --->  0.6235870786057701
# Checking cluster  0  of  KC1  and cluster  3  of  KC51
# dis_db --->  0.8997172928884594
# Checking cluster  0  of  KC1  and cluster  4  of  KC51
# dis_db --->  0.789858958907875
# Checking cluster  0  of  KC1  and cluster  5  of  KC51
# dis_db --->  0.9259692868254353
# num1, num2 =>  1 0
# num1, num2 =>  1 3
# Nearby clusters - look at merging  KC1  and  KC53
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC53  =  3
# Checking cluster  0  of  KC1  and cluster  0  of  KC53
# dis_db --->  0.7229455228369903
# Checking cluster  0  of  KC1  and cluster  1  of  KC53
# dis_db --->  0.9814842849909464
# Checking cluster  0  of  KC1  and cluster  2  of  KC53
# dis_db --->  0.8048529592089215
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# num1, num2 =>  1 2
# Nearby clusters - look at merging  KC1  and  KC57
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC57  =  2
# Checking cluster  0  of  KC1  and cluster  0  of  KC57
# dis_db --->  0.7380507875427715
# Checking cluster  0  of  KC1  and cluster  1  of  KC57
# dis_db --->  1.8259693781833126
# num1, num2 =>  1 5
# Nearby clusters - look at merging  KC1  and  KC58
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC58  =  5
# Checking cluster  0  of  KC1  and cluster  0  of  KC58
# dis_db --->  2.0225788551593613
# Checking cluster  0  of  KC1  and cluster  1  of  KC58
# dis_db --->  1.9326650573435662
# Checking cluster  0  of  KC1  and cluster  2  of  KC58
# dis_db --->  1.921376050595102
# Checking cluster  0  of  KC1  and cluster  3  of  KC58
# dis_db --->  1.7341735904660167
# Checking cluster  0  of  KC1  and cluster  4  of  KC58
# dis_db --->  2.1310014149374017
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# Nearby clusters - look at merging  KC1  and  KC61
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC61  =  1
# Checking cluster  0  of  KC1  and cluster  0  of  KC61
# dis_db --->  0.28883845565909544
# num1, num2 =>  1 4
# Nearby clusters - look at merging  KC1  and  KC62
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC62  =  4
# Checking cluster  0  of  KC1  and cluster  0  of  KC62
# dis_db --->  0.5181658692376516
# Checking cluster  0  of  KC1  and cluster  1  of  KC62
# dis_db --->  1.4403907900968622
# Checking cluster  0  of  KC1  and cluster  2  of  KC62
# dis_db --->  0.8100016648174382
# Checking cluster  0  of  KC1  and cluster  3  of  KC62
# dis_db --->  1.1416886606713583
# num1, num2 =>  1 1
# num1, num2 =>  1 1
# Nearby clusters - look at merging  KC1  and  KC64
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC64  =  1
# Checking cluster  0  of  KC1  and cluster  0  of  KC64
# dis_db --->  0.4493417158461731
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# Nearby clusters - look at merging  KC1  and  KC67
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC67  =  2
# Checking cluster  0  of  KC1  and cluster  0  of  KC67
# dis_db --->  0.2956914106817222
# Checking cluster  0  of  KC1  and cluster  1  of  KC67
# dis_db --->  1.2095612515998833
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# Nearby clusters - look at merging  KC1  and  KC69
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC69  =  1
# Checking cluster  0  of  KC1  and cluster  0  of  KC69
# dis_db --->  0.33812281387032966
# num1, num2 =>  1 4
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 6
# Nearby clusters - look at merging  KC1  and  KC73
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC73  =  6
# Checking cluster  0  of  KC1  and cluster  0  of  KC73
# dis_db --->  2.1653464446073287
# Checking cluster  0  of  KC1  and cluster  1  of  KC73
# dis_db --->  1.0821930012721346
# Checking cluster  0  of  KC1  and cluster  2  of  KC73
# dis_db --->  1.1746328170622062
# Checking cluster  0  of  KC1  and cluster  3  of  KC73
# dis_db --->  1.5972579041650568
# Checking cluster  0  of  KC1  and cluster  4  of  KC73
# dis_db --->  2.0168520355168904
# Checking cluster  0  of  KC1  and cluster  5  of  KC73
# dis_db --->  1.7614550179161577
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# Nearby clusters - look at merging  KC1  and  KC77
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC77  =  1
# Checking cluster  0  of  KC1  and cluster  0  of  KC77
# dis_db --->  1.6410492807303214
# num1, num2 =>  1 3
# Nearby clusters - look at merging  KC1  and  KC78
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC78  =  3
# Checking cluster  0  of  KC1  and cluster  0  of  KC78
# dis_db --->  0.7294384161952661
# Checking cluster  0  of  KC1  and cluster  1  of  KC78
# dis_db --->  1.3534654281661318
# Checking cluster  0  of  KC1  and cluster  2  of  KC78
# dis_db --->  1.226219083977141
# num1, num2 =>  1 0
# num1, num2 =>  1 3
# num1, num2 =>  1 1
# Nearby clusters - look at merging  KC1  and  KC81
# #, dbscan clusters in  KC1  =  1
# #, dbscan clusters in  KC81  =  1
# Checking cluster  0  of  KC1  and cluster  0  of  KC81
# dis_db --->  0.36168670832618166
# num1, num2 =>  1 0
# num1, num2 =>  1 4
# ...
# num1, num2 =>  0 0
# num1, num2 =>  0 4
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 1
# num1, num2 =>  0 0
# num1, num2 =>  0 2
# num1, num2 =>  0 1
# num1, num2 =>  0 6
# num1, num2 =>  0 0
# num1, num2 =>  0 1
# num1, num2 =>  0 1
# num1, num2 =>  0 0
# num1, num2 =>  0 2
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 3
# num1, num2 =>  0 0
# num1, num2 =>  0 1
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 1
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 2
# num1, num2 =>  0 2
# num1, num2 =>  0 0
# num1, num2 =>  0 1
# num1, num2 =>  0 2
# num1, num2 =>  0 4
# num1, num2 =>  0 0
# num1, num2 =>  0 2
# num1, num2 =>  0 2
# num1, num2 =>  0 0
# num1, num2 =>  0 1
# num1, num2 =>  0 1
# num1, num2 =>  0 4
# num1, num2 =>  0 2
# num1, num2 =>  0 0
# num1, num2 =>  0 1
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 1
# num1, num2 =>  0 1
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 2
# num1, num2 =>  0 0
# num1, num2 =>  0 1
# num1, num2 =>  0 1
# num1, num2 =>  0 4
# num1, num2 =>  0 0
#
#
# num1, num2 =>  2 3
# num1, num2 =>  2 1
# num1, num2 =>  2 2
# num1, num2 =>  2 0
# num1, num2 =>  2 0
# num1, num2 =>  2 1
# num1, num2 =>  2 1
# num1, num2 =>  2 2
# num1, num2 =>  2 0
# num1, num2 =>  2 0
# num1, num2 =>  2 2
# num1, num2 =>  2 0
# num1, num2 =>  2 0
# num1, num2 =>  2 1
# num1, num2 =>  2 0
# num1, num2 =>  2 8
# num1, num2 =>  2 1
# num1, num2 =>  2 0
# num1, num2 =>  2 1
# num1, num2 =>  2 0
# num1, num2 =>  2 0
# num1, num2 =>  2 4
# num1, num2 =>  2 2
# num1, num2 =>  2 1
# num1, num2 =>  2 0
# num1, num2 =>  2 2
# num1, num2 =>  2 0
# num1, num2 =>  2 0
# num1, num2 =>  2 0
# num1, num2 =>  2 0
# num1, num2 =>  2 1
# num1, num2 =>  2 2
# num1, num2 =>  2 2
# num1, num2 =>  2 0
# num1, num2 =>  2 0
# num1, num2 =>  2 0
# num1, num2 =>  2 0
# num1, num2 =>  2 0
# num1, num2 =>  2 2
# num1, num2 =>  2 2
# num1, num2 =>  2 2
# num1, num2 =>  2 0
# num1, num2 =>  2 1
# num1, num2 =>  2 2
# num1, num2 =>  2 1
# num1, num2 =>  2 1
# num1, num2 =>  2 3
# num1, num2 =>  2 0
# num1, num2 =>  2 2
# num1, num2 =>  2 1
# num1, num2 =>  2 4
# num1, num2 =>  2 6
# num1, num2 =>  2 0
# num1, num2 =>  2 3
# num1, num2 =>  2 0
# num1, num2 =>  2 0
# num1, num2 =>  2 2
# num1, num2 =>  2 2
# num1, num2 =>  2 5
# num1, num2 =>  2 0
# num1, num2 =>  2 0
# num1, num2 =>  2 1
# num1, num2 =>  2 4
# num1, num2 =>  2 1
# num1, num2 =>  2 1
# num1, num2 =>  2 0
# num1, num2 =>  2 0
# num1, num2 =>  2 2
# num1, num2 =>  2 0
# num1, num2 =>  2 1
# num1, num2 =>  2 4
# num1, num2 =>  2 0
# num1, num2 =>  2 0
# num1, num2 =>  2 6
# num1, num2 =>  2 2
# num1, num2 =>  2 0
# num1, num2 =>  2 0
# num1, num2 =>  2 1
# num1, num2 =>  2 3
# num1, num2 =>  2 0
# num1, num2 =>  2 3
# num1, num2 =>  2 1
# num1, num2 =>  2 0
# num1, num2 =>  2 4
# num1, num2 =>  2 0
# num1, num2 =>  2 0
# num1, num2 =>  2 0
# num1, num2 =>  2 0
# num1, num2 =>  2 1
# num1, num2 =>  2 0
# num1, num2 =>  2 2
# num1, num2 =>  2 1
# num1, num2 =>  2 6
# num1, num2 =>  2 0
# num1, num2 =>  2 1
# num1, num2 =>  2 1
# num1, num2 =>  2 0
# num1, num2 =>  2 2
# num1, num2 =>  2 0
# num1, num2 =>  2 0
# num1, num2 =>  2 3
# num1, num2 =>  2 0
# num1, num2 =>  2 1
# num1, num2 =>  2 0
# num1, num2 =>  2 0
# num1, num2 =>  2 1
# num1, num2 =>  2 0
# num1, num2 =>  2 0
# num1, num2 =>  2 0
# num1, num2 =>  2 2
# num1, num2 =>  2 2
# num1, num2 =>  2 0
# num1, num2 =>  2 1
# num1, num2 =>  2 2
# num1, num2 =>  2 4
# num1, num2 =>  2 0
# num1, num2 =>  2 2
# num1, num2 =>  2 2
# num1, num2 =>  2 0
# num1, num2 =>  2 1
# num1, num2 =>  2 1
# num1, num2 =>  2 4
# num1, num2 =>  2 2
# num1, num2 =>  2 0
# num1, num2 =>  2 1
# num1, num2 =>  2 0
# num1, num2 =>  2 0
# num1, num2 =>  2 1
# num1, num2 =>  2 1
# num1, num2 =>  2 0
# num1, num2 =>  2 0
# num1, num2 =>  2 2
# num1, num2 =>  2 0
# num1, num2 =>  2 1
# Nearby clusters - look at merging  KC131  and  KC133
# #, dbscan clusters in  KC131  =  2
# #, dbscan clusters in  KC133  =  1
# Checking cluster  0  of  KC131  and cluster  0  of  KC133
# dis_db --->  1.2805822097382709
# Checking cluster  1  of  KC131  and cluster  0  of  KC133
# dis_db --->  1.3599360405124787
# num1, num2 =>  2 1
# Nearby clusters - look at merging  KC131  and  KC134
# #, dbscan clusters in  KC131  =  2
# #, dbscan clusters in  KC134  =  1
# Checking cluster  0  of  KC131  and cluster  0  of  KC134
# dis_db --->  0.4129434123656713
# Checking cluster  1  of  KC131  and cluster  0  of  KC134
# dis_db --->  1.780992877581667
# num1, num2 =>  2 4
# Nearby clusters - look at merging  KC131  and  KC135
# #, dbscan clusters in  KC131  =  2
# #, dbscan clusters in  KC135  =  4
# Checking cluster  0  of  KC131  and cluster  0  of  KC135
# dis_db --->  1.493292788541309
# Checking cluster  0  of  KC131  and cluster  1  of  KC135
# dis_db --->  1.5637017367352626
# Checking cluster  0  of  KC131  and cluster  2  of  KC135
# dis_db --->  1.0742921080337517
# Checking cluster  0  of  KC131  and cluster  3  of  KC135
# dis_db --->  1.594656821216298
# Checking cluster  1  of  KC131  and cluster  0  of  KC135
# dis_db --->  2.3287917756421277
# Checking cluster  1  of  KC131  and cluster  1  of  KC135
# dis_db --->  2.358224078284036
# Checking cluster  1  of  KC131  and cluster  2  of  KC135
# dis_db --->  2.104505021586969
# Checking cluster  1  of  KC131  and cluster  3  of  KC135
# dis_db --->  2.649546379203006
# num1, num2 =>  2 0
#
#
# num1, num2 =>  0 3
# num1, num2 =>  0 1
# num1, num2 =>  0 2
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 1
# num1, num2 =>  0 1
# num1, num2 =>  0 2
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 2
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 1
# num1, num2 =>  0 0
# num1, num2 =>  0 8
# num1, num2 =>  0 1
# num1, num2 =>  0 0
# num1, num2 =>  0 1
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 4
# num1, num2 =>  0 2
# num1, num2 =>  0 1
# num1, num2 =>  0 0
# num1, num2 =>  0 2
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 1
# num1, num2 =>  0 2
# num1, num2 =>  0 2
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 2
# num1, num2 =>  0 2
# num1, num2 =>  0 2
# num1, num2 =>  0 0
# num1, num2 =>  0 1
# num1, num2 =>  0 2
# num1, num2 =>  0 1
# num1, num2 =>  0 1
# num1, num2 =>  0 3
# num1, num2 =>  0 0
# num1, num2 =>  0 2
# num1, num2 =>  0 1
# num1, num2 =>  0 4
# num1, num2 =>  0 6
# num1, num2 =>  0 0
# num1, num2 =>  0 3
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 2
# num1, num2 =>  0 2
# num1, num2 =>  0 5
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 1
# num1, num2 =>  0 4
# num1, num2 =>  0 1
# num1, num2 =>  0 1
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 2
# num1, num2 =>  0 0
# num1, num2 =>  0 1
# num1, num2 =>  0 4
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 6
# num1, num2 =>  0 2
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 1
# num1, num2 =>  0 3
# num1, num2 =>  0 0
# num1, num2 =>  0 3
# num1, num2 =>  0 1
# num1, num2 =>  0 0
# num1, num2 =>  0 4
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 1
# num1, num2 =>  0 0
# num1, num2 =>  0 2
# num1, num2 =>  0 1
# num1, num2 =>  0 6
# num1, num2 =>  0 0
# num1, num2 =>  0 1
# num1, num2 =>  0 1
# num1, num2 =>  0 0
# num1, num2 =>  0 2
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 3
# num1, num2 =>  0 0
# num1, num2 =>  0 1
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 1
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 2
# num1, num2 =>  0 2
# num1, num2 =>  0 0
# num1, num2 =>  0 1
# num1, num2 =>  0 2
# num1, num2 =>  0 4
# num1, num2 =>  0 0
# num1, num2 =>  0 2
# num1, num2 =>  0 2
# num1, num2 =>  0 0
# num1, num2 =>  0 1
# num1, num2 =>  0 1
# num1, num2 =>  0 4
# num1, num2 =>  0 2
# num1, num2 =>  0 0
# num1, num2 =>  0 1
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 1
# num1, num2 =>  0 1
# num1, num2 =>  0 0
# num1, num2 =>  0 0
# num1, num2 =>  0 2
# num1, num2 =>  0 0
# num1, num2 =>  0 1
# num1, num2 =>  0 1
# num1, num2 =>  0 4
# num1, num2 =>  0 0
#
#
# num1, num2 =>  1 3
# num1, num2 =>  1 1
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 1
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 0
# num1, num2 =>  1 8
# num1, num2 =>  1 1
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 4
# num1, num2 =>  1 2
# num1, num2 =>  1 1
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 2
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# num1, num2 =>  1 2
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 2
# num1, num2 =>  1 1
# num1, num2 =>  1 1
# num1, num2 =>  1 3
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# num1, num2 =>  1 1
# num1, num2 =>  1 4
# num1, num2 =>  1 6
# num1, num2 =>  1 0
# num1, num2 =>  1 3
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# num1, num2 =>  1 2
# num1, num2 =>  1 5
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 4
# num1, num2 =>  1 1
# num1, num2 =>  1 1
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 4
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 6
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 3
# num1, num2 =>  1 0
# num1, num2 =>  1 3
# num1, num2 =>  1 1
# num1, num2 =>  1 0
# num1, num2 =>  1 4
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# num1, num2 =>  1 1
# num1, num2 =>  1 6
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 1
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 3
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 2
# num1, num2 =>  1 4
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 1
# num1, num2 =>  1 4
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 1
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 1
# num1, num2 =>  1 4
# num1, num2 =>  1 0
#
#
# num1, num2 =>  1 3
# num1, num2 =>  1 1
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 1
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 0
# num1, num2 =>  1 8
# num1, num2 =>  1 1
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 4
# num1, num2 =>  1 2
# num1, num2 =>  1 1
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 2
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# num1, num2 =>  1 2
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 2
# num1, num2 =>  1 1
# num1, num2 =>  1 1
# num1, num2 =>  1 3
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# num1, num2 =>  1 1
# num1, num2 =>  1 4
# num1, num2 =>  1 6
# num1, num2 =>  1 0
# num1, num2 =>  1 3
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# num1, num2 =>  1 2
# num1, num2 =>  1 5
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 4
# num1, num2 =>  1 1
# num1, num2 =>  1 1
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 4
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 6
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 3
# num1, num2 =>  1 0
# num1, num2 =>  1 3
# num1, num2 =>  1 1
# num1, num2 =>  1 0
# num1, num2 =>  1 4
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# num1, num2 =>  1 1
# num1, num2 =>  1 6
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 1
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 3
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 2
# num1, num2 =>  1 4
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 1
# num1, num2 =>  1 4
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 1
# num1, num2 =>  1 0
# num1, num2 =>  1 0
# num1, num2 =>  1 2
# num1, num2 =>  1 0
# num1, num2 =>  1 1
# num1, num2 =>  1 1
# num1, num2 =>  1 4
# Nearby clusters - look at merging  KC134  and  KC135
# #, dbscan clusters in  KC134  =  1
# #, dbscan clusters in  KC135  =  4
# Checking cluster  0  of  KC134  and cluster  0  of  KC135
# dis_db --->  2.3942541815291087
# Checking cluster  0  of  KC134  and cluster  1  of  KC135
# dis_db --->  2.378673770616796
# Checking cluster  0  of  KC134  and cluster  2  of  KC135
# dis_db --->  1.5686558390382521
# Checking cluster  0  of  KC134  and cluster  3  of  KC135
# dis_db --->  2.0512432051840364
# num1, num2 =>  1 0
#
#
# num1, num2 =>  4 3
# num1, num2 =>  4 1
# num1, num2 =>  4 2
# num1, num2 =>  4 0
# num1, num2 =>  4 0
# num1, num2 =>  4 1
# num1, num2 =>  4 1
# num1, num2 =>  4 2
# num1, num2 =>  4 0
# num1, num2 =>  4 0
# num1, num2 =>  4 2
# num1, num2 =>  4 0
# num1, num2 =>  4 0
# num1, num2 =>  4 1
# num1, num2 =>  4 0
# num1, num2 =>  4 8
# num1, num2 =>  4 1
# num1, num2 =>  4 0
# num1, num2 =>  4 1
# num1, num2 =>  4 0
# num1, num2 =>  4 0
# num1, num2 =>  4 4
# num1, num2 =>  4 2
# num1, num2 =>  4 1
# num1, num2 =>  4 0
# num1, num2 =>  4 2
# num1, num2 =>  4 0
# num1, num2 =>  4 0
# num1, num2 =>  4 0
# num1, num2 =>  4 0
# num1, num2 =>  4 1
# num1, num2 =>  4 2
# num1, num2 =>  4 2
# num1, num2 =>  4 0
# num1, num2 =>  4 0
# num1, num2 =>  4 0
# num1, num2 =>  4 0
# num1, num2 =>  4 0
# num1, num2 =>  4 2
# num1, num2 =>  4 2
# num1, num2 =>  4 2
# num1, num2 =>  4 0
# num1, num2 =>  4 1
# num1, num2 =>  4 2
# num1, num2 =>  4 1
# num1, num2 =>  4 1
# num1, num2 =>  4 3
# num1, num2 =>  4 0
# num1, num2 =>  4 2
# num1, num2 =>  4 1
# num1, num2 =>  4 4
# num1, num2 =>  4 6
# num1, num2 =>  4 0
# num1, num2 =>  4 3
# num1, num2 =>  4 0
# num1, num2 =>  4 0
# num1, num2 =>  4 2
# num1, num2 =>  4 2
# num1, num2 =>  4 5
# num1, num2 =>  4 0
# num1, num2 =>  4 0
# num1, num2 =>  4 1
# num1, num2 =>  4 4
# num1, num2 =>  4 1
# num1, num2 =>  4 1
# num1, num2 =>  4 0
# num1, num2 =>  4 0
# num1, num2 =>  4 2
# num1, num2 =>  4 0
# num1, num2 =>  4 1
# num1, num2 =>  4 4
# num1, num2 =>  4 0
# num1, num2 =>  4 0
# num1, num2 =>  4 6
# num1, num2 =>  4 2
# num1, num2 =>  4 0
# num1, num2 =>  4 0
# num1, num2 =>  4 1
# num1, num2 =>  4 3
# num1, num2 =>  4 0
# num1, num2 =>  4 3
# num1, num2 =>  4 1
# num1, num2 =>  4 0
# num1, num2 =>  4 4
# num1, num2 =>  4 0
# num1, num2 =>  4 0
# num1, num2 =>  4 0
# num1, num2 =>  4 0
# num1, num2 =>  4 1
# num1, num2 =>  4 0
# num1, num2 =>  4 2
# num1, num2 =>  4 1
# num1, num2 =>  4 6
# num1, num2 =>  4 0
# num1, num2 =>  4 1
# num1, num2 =>  4 1
# num1, num2 =>  4 0
# num1, num2 =>  4 2
# num1, num2 =>  4 0
# num1, num2 =>  4 0
# num1, num2 =>  4 3
# num1, num2 =>  4 0
# num1, num2 =>  4 1
# num1, num2 =>  4 0
# num1, num2 =>  4 0
# num1, num2 =>  4 1
# num1, num2 =>  4 0
# num1, num2 =>  4 0
# num1, num2 =>  4 0
# num1, num2 =>  4 2
# num1, num2 =>  4 2
# num1, num2 =>  4 0
# num1, num2 =>  4 1
# num1, num2 =>  4 2
# num1, num2 =>  4 4
# num1, num2 =>  4 0
# num1, num2 =>  4 2
# num1, num2 =>  4 2
# num1, num2 =>  4 0
# num1, num2 =>  4 1
# num1, num2 =>  4 1
# num1, num2 =>  4 4
# num1, num2 =>  4 2
# num1, num2 =>  4 0
# num1, num2 =>  4 1
# num1, num2 =>  4 0
# num1, num2 =>  4 0
# num1, num2 =>  4 1
# num1, num2 =>  4 1
# num1, num2 =>  4 0
# num1, num2 =>  4 0
# num1, num2 =>  4 2
# num1, num2 =>  4 0
# num1, num2 =>  4 1
# num1, num2 =>  4 1
# num1, num2 =>  4 4
# num1, num2 =>  4 0

# %%
for itm in flag_ref.keys():
    print(itm)
# Out:
# ('a_0', 'c_0')
# ('b_1', 'd_0')
# ('a_0', 'c_1')
# ('a_0', 'c_2')
# ('b_5', 'd_0')
# ('b_6', 'd_0')
# ('b_10', 'd_0')
# ('b_10', 'd_1')
# ('b_13', 'd_0')
# ('b_18', 'd_0')
# ('b_22', 'd_0')
# ('b_22', 'd_1')
# ('b_23', 'd_0')
# ('b_25', 'd_0')
# ('b_25', 'd_1')
# ('b_30', 'd_0')
# ('b_31', 'd_0')
# ('b_31', 'd_1')
# ('b_39', 'd_0')
# ('b_39', 'd_1')
# ('b_40', 'd_0')
# ('b_40', 'd_1')
# ('b_43', 'd_0')
# ('b_43', 'd_1')
# ('b_45', 'd_0')
# ('b_46', 'd_0')
# ('b_46', 'd_1')
# ('b_46', 'd_2')
# ('b_48', 'd_0')
# ('b_48', 'd_1')
# ('b_49', 'd_0')
# ('b_51', 'd_0')
# ('b_51', 'd_1')
# ('b_51', 'd_2')
# ('b_51', 'd_3')
# ('b_51', 'd_4')
# ('b_51', 'd_5')
# ('b_56', 'd_0')
# ('b_56', 'd_1')
# ('b_57', 'd_0')
# ('b_57', 'd_1')
# ('b_58', 'd_0')
# ('b_58', 'd_1')
# ('b_58', 'd_2')
# ('b_58', 'd_3')
# ('b_58', 'd_4')
# ('b_62', 'd_0')
# ('b_62', 'd_1')
# ('b_62', 'd_2')
# ('b_62', 'd_3')
# ('b_63', 'd_0')
# ('b_67', 'd_0')
# ('b_67', 'd_1')
# ('b_69', 'd_0')
# ('b_73', 'd_0')
# ('b_73', 'd_1')
# ('b_73', 'd_2')
# ('b_73', 'd_3')
# ('b_73', 'd_4')
# ('b_73', 'd_5')
# ('b_74', 'd_0')
# ('b_74', 'd_1')
# ('b_77', 'd_0')
# ('b_78', 'd_0')
# ('b_78', 'd_1')
# ('b_78', 'd_2')
# ('b_80', 'd_0')
# ('b_80', 'd_1')
# ('b_80', 'd_2')
# ('b_81', 'd_0')
# ('b_83', 'd_0')
# ('b_83', 'd_1')
# ('b_83', 'd_2')
# ('b_83', 'd_3')
# ('b_88', 'd_0')
# ('b_90', 'd_0')
# ('b_90', 'd_1')
# ('b_91', 'd_0')
# ('b_94', 'd_0')
# ('b_95', 'd_0')
# ('b_97', 'd_0')
# ('b_97', 'd_1')
# ('b_100', 'd_0')
# ('b_100', 'd_1')
# ('b_100', 'd_2')
# ('b_102', 'd_0')
# ('b_105', 'd_0')
# ('b_109', 'd_0')
# ('b_109', 'd_1')
# ('b_110', 'd_0')
# ('b_110', 'd_1')
# ('b_113', 'd_0')
# ('b_113', 'd_1')
# ('b_117', 'd_0')
# ('b_117', 'd_1')
# ('b_121', 'd_0')
# ('b_121', 'd_1')
# ('b_121', 'd_2')
# ('b_121', 'd_3')
# ('b_122', 'd_0')
# ('b_122', 'd_1')
# ('b_124', 'd_0')
# ('b_127', 'd_0')
# ('b_128', 'd_0')
# ('b_131', 'd_0')
# ('b_131', 'd_1')
# ('b_133', 'd_0')
# ('b_134', 'd_0')
# ('a_1', 'c_0')
# ('b_7', 'd_0')
# ('b_7', 'd_1')
# ('b_15', 'd_0')
# ('b_15', 'd_1')
# ('b_15', 'd_2')
# ('b_15', 'd_3')
# ('b_15', 'd_4')
# ('b_15', 'd_5')
# ('b_15', 'd_6')
# ('b_15', 'd_7')
# ('b_21', 'd_0')
# ('b_21', 'd_1')
# ('b_21', 'd_2')
# ('b_21', 'd_3')
# ('b_38', 'd_0')
# ('b_38', 'd_1')
# ('b_44', 'd_0')
# ('b_53', 'd_0')
# ('b_53', 'd_1')
# ('b_53', 'd_2')
# ('b_61', 'd_0')
# ('b_64', 'd_0')
# ('b_92', 'd_0')
# ('b_92', 'd_1')
# ('b_92', 'd_2')
# ('b_92', 'd_3')
# ('b_92', 'd_4')
# ('b_92', 'd_5')
# ('b_114', 'd_0')
# ('b_114', 'd_1')
# ('b_114', 'd_2')
# ('b_114', 'd_3')
# ('b_116', 'd_0')
# ('b_116', 'd_1')
# ('b_119', 'd_0')
# ('b_135', 'd_0')
# ('b_135', 'd_1')
# ('b_135', 'd_2')
# ('b_135', 'd_3')
# ('a_2', 'c_0')
# ('a_2', 'c_1')
# ('b_16', 'd_0')
# ('b_32', 'd_0')
# ('b_32', 'd_1')
# ('b_42', 'd_0')
# ('b_70', 'd_0')
# ('b_70', 'd_1')
# ('b_70', 'd_2')
# ('b_70', 'd_3')
# ('b_112', 'd_0')
# ('b_120', 'd_0')
# ('a_5', 'c_0')
# ('a_6', 'c_0')
# ('b_50', 'd_0')
# ('b_50', 'd_1')
# ('b_50', 'd_2')
# ('b_50', 'd_3')
# ('a_7', 'c_0')
# ('a_7', 'c_1')
# ('a_10', 'c_0')
# ('a_10', 'c_1')
# ('a_13', 'c_0')
# ('a_15', 'c_0')
# ('a_15', 'c_1')
# ('a_15', 'c_2')
# ('a_15', 'c_3')
# ('a_15', 'c_4')
# ('a_15', 'c_5')
# ('a_15', 'c_6')
# ('a_15', 'c_7')
# ('a_16', 'c_0')
# ('a_18', 'c_0')
# ('a_21', 'c_0')
# ('a_21', 'c_1')
# ('a_21', 'c_2')
# ('a_21', 'c_3')
# ('a_22', 'c_0')
# ('a_22', 'c_1')
# ('a_23', 'c_0')
# ('a_25', 'c_0')
# ('a_25', 'c_1')
# ('a_30', 'c_0')
# ('a_31', 'c_0')
# ('a_31', 'c_1')
# ('a_32', 'c_0')
# ('a_32', 'c_1')
# ('a_38', 'c_0')
# ('a_38', 'c_1')
# ('a_39', 'c_0')
# ('a_39', 'c_1')
# ('a_40', 'c_0')
# ('a_40', 'c_1')
# ('a_42', 'c_0')
# ('a_43', 'c_0')
# ('a_43', 'c_1')
# ('a_44', 'c_0')
# ('a_45', 'c_0')
# ('a_46', 'c_0')
# ('a_46', 'c_1')
# ('a_46', 'c_2')
# ('a_48', 'c_0')
# ('a_48', 'c_1')
# ('a_49', 'c_0')
# ('a_50', 'c_0')
# ('a_50', 'c_1')
# ('a_50', 'c_2')
# ('a_50', 'c_3')
# ('a_51', 'c_0')
# ('a_51', 'c_1')
# ('a_51', 'c_2')
# ('a_51', 'c_3')
# ('a_51', 'c_4')
# ('a_51', 'c_5')
# ('a_53', 'c_0')
# ('a_53', 'c_1')
# ('a_53', 'c_2')
# ('a_56', 'c_0')
# ('a_56', 'c_1')
# ('a_57', 'c_0')
# ('a_57', 'c_1')
# ('a_58', 'c_0')
# ('a_58', 'c_1')
# ('a_58', 'c_2')
# ('a_58', 'c_3')
# ('a_58', 'c_4')
# ('a_61', 'c_0')
# ('a_62', 'c_0')
# ('a_62', 'c_1')
# ('a_62', 'c_2')
# ('a_62', 'c_3')
# ('a_63', 'c_0')
# ('a_64', 'c_0')
# ('a_67', 'c_0')
# ('a_67', 'c_1')
# ('a_69', 'c_0')
# ('a_70', 'c_0')
# ('a_70', 'c_1')
# ('a_70', 'c_2')
# ('a_70', 'c_3')
# ('a_73', 'c_0')
# ('a_73', 'c_1')
# ('a_73', 'c_2')
# ('a_73', 'c_3')
# ('a_73', 'c_4')
# ('a_73', 'c_5')
# ('a_74', 'c_0')
# ('a_74', 'c_1')
# ('a_77', 'c_0')
# ('a_78', 'c_0')
# ('a_78', 'c_1')
# ('a_78', 'c_2')
# ('a_80', 'c_0')
# ('a_80', 'c_1')
# ('a_80', 'c_2')
# ('a_81', 'c_0')
# ('a_83', 'c_0')
# ('a_83', 'c_1')
# ('a_83', 'c_2')
# ('a_83', 'c_3')
# ('a_88', 'c_0')
# ('a_90', 'c_0')
# ('a_90', 'c_1')
# ('a_91', 'c_0')
# ('a_92', 'c_0')
# ('a_92', 'c_1')
# ('a_92', 'c_2')
# ('a_92', 'c_3')
# ('a_92', 'c_4')
# ('a_92', 'c_5')
# ('a_94', 'c_0')
# ('a_95', 'c_0')
# ('a_97', 'c_0')
# ('a_97', 'c_1')
# ('a_100', 'c_0')
# ('a_100', 'c_1')
# ('a_100', 'c_2')
# ('a_102', 'c_0')
# ('a_105', 'c_0')
# ('a_109', 'c_0')
# ('a_109', 'c_1')
# ('a_110', 'c_0')
# ('a_110', 'c_1')
# ('a_112', 'c_0')
# ('a_113', 'c_0')
# ('a_113', 'c_1')
# ('a_114', 'c_0')
# ('a_114', 'c_1')
# ('a_114', 'c_2')
# ('a_114', 'c_3')
# ('a_116', 'c_0')
# ('a_116', 'c_1')
# ('a_117', 'c_0')
# ('a_117', 'c_1')
# ('a_119', 'c_0')
# ('a_120', 'c_0')
# ('a_121', 'c_0')
# ('a_121', 'c_1')
# ('a_121', 'c_2')
# ('a_121', 'c_3')
# ('a_122', 'c_0')
# ('a_122', 'c_1')
# ('a_124', 'c_0')
# ('a_127', 'c_0')
# ('a_128', 'c_0')
# ('a_131', 'c_0')
# ('a_131', 'c_1')
# ('a_134', 'c_0')

# %%
# Create dataset with merged clusters

final_data = pd.DataFrame(columns=X.columns)
final_data.head()
# Out:
# Empty DataFrame
# Columns: [fLength, fWidth, fSize, fConc, fConc1, fAsym, fM3Long, fM3Trans, fAlpha, fDist]
# Index: []

# %%
total = 0

for tup in flag_ref.keys():
#     print(tup)
    group = tup[0].split('_')[1]
    cluster = tup[1].split('_')[1]
    samples = dbscan_clusters['KC'+str(group)][str(cluster)]
    final_data = final_data.append(samples)
#     print(samples.head(1))
final_data.head()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# ...
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\3599748851.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_data = final_data.append(samples)
#       fLength    fWidth     fSize     fConc    fConc1     fAsym   fM3Long  \
# 306 -0.417757 -0.371761 -0.064574 -0.122681 -0.308187 -0.104978  0.225044
# 382 -0.607693 -0.244591 -0.208887 -0.231538 -0.336240 -0.416584  0.037859
# 519 -0.099511 -0.499279  0.027261 -0.412055 -0.542560 -0.353685  0.376796
# 523 -0.225399 -0.433503  0.074025 -0.577802 -0.674677 -0.742796  0.282700
# 631 -0.449497 -0.544129 -0.577497  0.021733 -0.127205 -0.785632  0.158862
#
#      fM3Trans    fAlpha     fDist
# 306  0.320988 -0.534641 -0.371472
# 382 -0.553512 -0.932060 -0.083073
# 519 -0.298025 -0.860926  0.531059
# 523 -0.140248 -1.042473  0.044239
# 631 -0.343941 -0.802565 -0.822082

# %%
final_data
# Out:
#         fLength    fWidth     fSize     fConc    fConc1     fAsym   fM3Long  \
# 306   -0.417757 -0.371761 -0.064574 -0.122681 -0.308187 -0.104978  0.225044
# 382   -0.607693 -0.244591 -0.208887 -0.231538 -0.336240 -0.416584  0.037859
# 519   -0.099511 -0.499279  0.027261 -0.412055 -0.542560 -0.353685  0.376796
# 523   -0.225399 -0.433503  0.074025 -0.577802 -0.674677 -0.742796  0.282700
# 631   -0.449497 -0.544129 -0.577497  0.021733 -0.127205 -0.785632  0.158862
# ...         ...       ...       ...       ...       ...       ...       ...
# 17763 -0.752156 -0.464682 -0.543429  0.950574  1.371331 -0.143583 -0.495083
# 18456 -0.802643 -0.675425 -0.789733  1.244325  0.919779 -0.332036 -0.392850
# 18733 -0.569465 -0.778916 -0.896380  0.936899  0.660974 -0.164215  0.095029
# 18855 -0.760895 -0.675747 -0.882203  1.258000  0.765039  0.197469 -0.326501
# 18982 -0.708404 -0.606706 -0.980386  1.152972  0.812095 -0.184198 -0.249762
#
#        fM3Trans    fAlpha     fDist
# 306    0.320988 -0.534641 -0.371472
# 382   -0.553512 -0.932060 -0.083073
# 519   -0.298025 -0.860926  0.531059
# 523   -0.140248 -1.042473  0.044239
# 631   -0.343941 -0.802565 -0.822082
# ...         ...       ...       ...
# 17763  0.566622 -0.670565 -0.635142
# 18456 -0.265619 -0.991356 -0.828023
# 18733 -0.275515 -0.760662 -0.343170
# 18855 -0.244502 -0.845679 -0.348051
# 18982 -0.228998 -0.660524 -0.106262
#
# [21571 rows x 10 columns]

# %%
final_data = final_data.drop_duplicates()
final_data
# Out:
#         fLength    fWidth     fSize     fConc    fConc1     fAsym   fM3Long  \
# 306   -0.417757 -0.371761 -0.064574 -0.122681 -0.308187 -0.104978  0.225044
# 382   -0.607693 -0.244591 -0.208887 -0.231538 -0.336240 -0.416584  0.037859
# 519   -0.099511 -0.499279  0.027261 -0.412055 -0.542560 -0.353685  0.376796
# 523   -0.225399 -0.433503  0.074025 -0.577802 -0.674677 -0.742796  0.282700
# 631   -0.449497 -0.544129 -0.577497  0.021733 -0.127205 -0.785632  0.158862
# ...         ...       ...       ...       ...       ...       ...       ...
# 4225   1.185562  1.701328  3.047662 -1.639023 -1.575970  1.364645  1.387199
# 4598   1.004221  1.578323  2.855104 -1.538918 -1.480049  0.938825  1.178671
# 6939   1.290935  1.699927  3.288041 -1.678956 -1.598593  1.206765  1.473001
# 8786   1.182257  1.546391  3.032215 -1.601826 -1.535249  0.619388  1.249668
# 12034  1.050888  1.648699  3.083634 -1.685520 -1.613072  1.088050  1.341047
#
#        fM3Trans    fAlpha     fDist
# 306    0.320988 -0.534641 -0.371472
# 382   -0.553512 -0.932060 -0.083073
# 519   -0.298025 -0.860926  0.531059
# 523   -0.140248 -1.042473  0.044239
# 631   -0.343941 -0.802565 -0.822082
# ...         ...       ...       ...
# 4225  -1.102417 -0.992942  1.241191
# 4598  -1.775754 -1.033053  1.567179
# 6939  -1.362586 -0.994770  1.321186
# 8786  -1.417726 -0.927390  1.292763
# 12034 -1.683311 -0.959651  1.022804
#
# [10916 rows x 10 columns]

# %% [markdown]
# ###### Run DBSCAN algorithmin clusters with same flag

# %%
labels = []
print(counter)
# for i in range(1,  counter):
#     clusters_with_same_flag = [clu for clu, flag_value in flag_ref.items() if flag_value == i]
# #     labels.append(dbscan(clusters_with_same_flag, epsilon, MinPts))
labels = DBSCAN(eps=0.6, min_samples=4).fit(final_data).labels_
# print("clusters with same flag = ", clusters_with_same_flag)
print("FINAL LABELS ->", labels)
labels
# Out:
# 2
# FINAL LABELS -> [ 0  0  0 ... 41 41 41]
# array([ 0,  0,  0, ..., 41, 41, 41], dtype=int64)

# %%
final_data['cluster'] = labels
final_data
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17868\611591970.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_data['cluster'] = labels
#         fLength    fWidth     fSize     fConc    fConc1     fAsym   fM3Long  \
# 306   -0.417757 -0.371761 -0.064574 -0.122681 -0.308187 -0.104978  0.225044
# 382   -0.607693 -0.244591 -0.208887 -0.231538 -0.336240 -0.416584  0.037859
# 519   -0.099511 -0.499279  0.027261 -0.412055 -0.542560 -0.353685  0.376796
# 523   -0.225399 -0.433503  0.074025 -0.577802 -0.674677 -0.742796  0.282700
# 631   -0.449497 -0.544129 -0.577497  0.021733 -0.127205 -0.785632  0.158862
# ...         ...       ...       ...       ...       ...       ...       ...
# 4225   1.185562  1.701328  3.047662 -1.639023 -1.575970  1.364645  1.387199
# 4598   1.004221  1.578323  2.855104 -1.538918 -1.480049  0.938825  1.178671
# 6939   1.290935  1.699927  3.288041 -1.678956 -1.598593  1.206765  1.473001
# 8786   1.182257  1.546391  3.032215 -1.601826 -1.535249  0.619388  1.249668
# 12034  1.050888  1.648699  3.083634 -1.685520 -1.613072  1.088050  1.341047
#
#        fM3Trans    fAlpha     fDist  cluster
# 306    0.320988 -0.534641 -0.371472        0
# 382   -0.553512 -0.932060 -0.083073        0
# 519   -0.298025 -0.860926  0.531059        0
# 523   -0.140248 -1.042473  0.044239        0
# 631   -0.343941 -0.802565 -0.822082        0
# ...         ...       ...       ...      ...
# 4225  -1.102417 -0.992942  1.241191       41
# 4598  -1.775754 -1.033053  1.567179       41
# 6939  -1.362586 -0.994770  1.321186       41
# 8786  -1.417726 -0.927390  1.292763       41
# 12034 -1.683311 -0.959651  1.022804       41
#
# [10916 rows x 11 columns]

# %%
# Performing PCA so that we can plot
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA(n_components = 3)
Xt = pca.fit_transform(final_data)
plot = plt.scatter(Xt[:,0], Xt[:, 1], c=labels)
plt.show()

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(projection='3d')
ax.scatter(Xt[:,0], Xt[:,1], Xt[:,2], c=labels)
plt.show()

# %%
# separating out just the features from each cluster

# KC1_X = KC1.drop(['cluster'], axis=1)
# KC2_X = KC1.drop(['cluster'], axis=1)
# KC3_X = KC1.drop(['cluster'], axis=1)

# %%
# running dbscan on each of these clusters (abalone)

# db_KC1 = DBSCAN(eps=0.035, min_samples=4).fit(KC1_X)
# db_KC2 = DBSCAN(eps=0.035, min_samples=4).fit(KC2_X)
# db_KC3 = DBSCAN(eps=0.035, min_samples=4).fit(KC3_X)

# set(db_KC1.labels_)

# %%
# Core samples
# len(db_KC1.core_sample_indices_)

# %%
# Creating an array to store cluster information obtained from each DBSCAN execution
cluster_info = {}

# %%
# Storing info for KC1 DBSCAN clusters
# s = set(db_KC1.labels_)


# cluster_info['KC1'] = {
#     "num_clust": len(s),
#     "clusters": s,
#     "predictions": db_KC1.labels_
# }

# cluster_info

# %%
# Storing info for KC2 DBSCAN clusters
# s = set(db_KC2.labels_)


# cluster_info['KC2'] = {
#     "num_clust": len(s),
#     "clusters": s,
#     "predictions": db_KC2.labels_
# }

# cluster_info

# %%
# Storing info for KC3 DBSCAN clusters
# s = set(db_KC3.labels_)


# cluster_info['KC3'] = {
#     "num_clust": len(s),
#     "clusters": s,
#     "predictions": db_KC3.labels_
# }

# cluster_info

# %% [markdown]
# #### Merging clusters

# %% [markdown]
# Step 1:
#
# In this step, we examine each of the groups obtained from KMeans clustering to see if any of the clusters can be merged. The authors proposed the following distance formula for calculating pairwise distances between the groups:
# <br><br>
# <div style="text-align: center;">
#     <i>
#         <strong>dis_K<sub>ij</sub> = dis_KC<sub>ij</sub> + (dis_r<sub>i</sub> - dis_r<sub>j</sub></strong>
#     </i>, where
#     <br><br>
#     <i><strong>dis_K<sub>ij</sub></strong></i> = distance between clusters <i>i</i> and <i>j</i>,
#     <br>
#     <i><strong>dis_KC<sub>ij</sub></strong></i> = distance between the cluster centers of clusters <i>i</i> and <i>j</i>,
#     <br>
#     <i><strong>dis_r<sub>i</sub></strong></i> = distance of the furthest point in cluster <i>i</i> to the corresponding center, and
#     <br>
#     <i><strong>dis_r<sub>j</sub></strong></i> = distance of the furthest point in cluster <i>j</i> to the corresponding center
# </div>

# %%
# We will be using the Euclidean distance
from scipy.spatial import distance

# %%
# Saving centers and farthest point of each cluster in a dictionary
km_centers = {}
farthest_point = {}

for i in range(0, num_clusters):
    # finding the center of cluster i
    label = "KC" + str(i)
    center = km_abalone.cluster_centers_[i]
    km_centers[label] = center
    
    # iterating through each sample in cluster i to find the farthest point    
    samples = cluster_features[label].to_numpy() 
    max_dist = 0
    for sample in samples:        
        dist = distance.euclidean(np.array(sample), center)
        if dist >= max_dist:
            farthest_point[label] = {"point": np.array(sample),"distance": dist}
            max_dist = dist
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 15
#      13 max_dist = 0
#      14 for sample in samples:
# ---> 15     dist = distance.euclidean(np.array(sample), center)
#      16     if dist >= max_dist:
#      17         farthest_point[label] = {"point": np.array(sample),"distance": dist}
#
# File ~\anaconda3\lib\site-packages\scipy\spatial\distance.py:520, in euclidean(u, v, w)
#     484 def euclidean(u, v, w=None):
#     485     """
#     486     Computes the Euclidean distance between two 1-D arrays.
#     487
#    (...)
#     518
#     519     """
# --> 520     return minkowski(u, v, p=2, w=w)
#
# File ~\anaconda3\lib\site-packages\scipy\spatial\distance.py:467, in minkowski(u, v, p, w)
#     465 if p <= 0:
#     466     raise ValueError("p must be greater than 0")
# --> 467 u_v = u - v
#     468 if w is not None:
#     469     w = _validate_weights(w)
#
# ValueError: operands could not be broadcast together with shapes (11,) (10,)

# %%
# Computing pairwise distances of each cluster using the distance formula defined earlier
pairwise_distance = np.full((num_clusters, num_clusters), np.inf)

for i in range(0, num_clusters):
    ci = "KC" + str(i) # label of cluster i
    
    for j in range(i + 1, num_clusters):
        cj = "KC" + str(j) # label of cluster j
        if i == j:
            pairwise_distance[i][j] = 0
        else:
            pairwise_distance[i][j] = distance.euclidean(km_centers[ci], km_centers[cj]) 
            + (farthest_point[ci]["distance"] - farthest_point[cj]["distance"])
pairwise_distance

# %%
# We define a parameter epsilon such that all clusters whose distances are less than epsilon are merged
epsilon = 10.0

# %%
to_merge = set()
for i in range(0, num_clusters):
    for j in range(i+1, num_clusters):
        if pairwise_distance[i][j] < epsilon:
            if (j, i) not in to_merge:
                to_merge.add((i, j))
            
print("Going to merge ", len(to_merge)," clusters")
print("Clusters to be merged are ", to_merge)

merged_centroids = {}

for i, j in to_merge:
    # Clusters to be merged
    c1 = "KC" + str(i)
    c2 = "KC" + str(j)
    mean = (km_abalone.cluster_centers_[i] + km_abalone.cluster_centers_[j]) / 2
    merged_centroids["KC"+str(i)+"_"+str(j)] = mean
    clustered_abalone.loc[clustered_abalone["cluster"] == c1, "cluster"] = "KC" + str(i) + "_" + str(j)
    clustered_abalone.loc[clustered_abalone["cluster"] == c2, "cluster"] = "KC" + str(i) + "_" + str(j)

merged_centroids

# %%
for i in range(0, num_clusters):
    for j in range(i+1, num_clusters):
        if pairwise_distance[i][j] < epsilon:

# %%
clustered_abalone

# %%
merged_labels = pd.unique(clustered_abalone['cluster'])
n = len(pd.unique(clustered_abalone['cluster']))
print("Number of clusters after merging", n)
merged_labels

# %% [markdown]
# We have pruned 12 clusters from the dataset. Now we will check the possibility of merging DBSCAN clusters within each of the clusters obtained in the previous step.

# %% [markdown]
# #### Running DBSCAN on each of the clusters generated by the KMeans++ clustering step

# %% [markdown]
# Collecting the samples and features of each cluster

# %%
# Samples
merged_samples = {}

for label in merged_labels:
    merged_samples[label] = clustered_abalone.loc[clustered_abalone['cluster'] == label]

# features
merged_cluster_features = {}
for label in merged_labels:
    merged_cluster_features[label] = merged_samples[label].drop(['cluster'], axis=1)

# %%
# Create a dictionary to store the DBSCAN models corresponding to each of the 50 clusters
dbscan_clusters = {}
counter = 0
for cluster in merged_cluster_features.keys():
    dbscan_clusters[cluster] = DBSCAN(eps=0.49, min_samples=4).fit(merged_cluster_features[cluster])

# %%
for cluster in merged_cluster_features.keys():
    print("DBSCAN result for cluster ", cluster, " = ", dbscan_clusters[cluster].labels_)
